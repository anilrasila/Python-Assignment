# %% [markdown]
# # ASSIGNMENT 21

# %% [markdown]
# ## 1. Add the current date to the text file today.txt as a string.

# %%
import datetime
# Code to Add current date to the today.txt file
file = open('today.txt','w')
file.write(datetime.datetime.now().strftime("%d-%m-%Y"))
file.close()
# Code to Read current date from today.txt file
file = open('today.txt','r')
print(file.read())
file.close()
# Out:
# 21-12-2022

# %% [markdown]
# ## 2. Read the text file today.txt into the string today_string

# %%
file = open('today.txt','r')
today_string = file.read()
print(today_string)
# Out:
# 21-12-2022

# %% [markdown]
# ## 3. Parse the date from today_string.

# %%
from datetime import datetime
parsed_data = datetime.strptime(today_string, '%d-%m-%Y')
print(parsed_data)
# Out:
# 2022-12-21 00:00:00

# %% [markdown]
# ## 4. List the files in your current directory

# %%
import os
for folders, subfolders, files in os.walk(os.getcwd()):
    for file in files:
        print(file)
# Out:
# .condarc
# .dbshell
# .mongorc.js
# .python_history
# 22.Assignment_22.ipynb
# Admission_Lr_model.pickle
# ALL   Practive.ipynb
# application_log.txt
# ASDFHJK.ipynb
# ASSIGNMENT 01.ipynb
# ASSIGNMENT 02.ipynb
# ASSIGNMENT 03.ipynb
# ASSIGNMENT 04.ipynb
# ASSIGNMENT 05.ipynb
# ASSIGNMENT 06.ipynb
# ASSIGNMENT 07.ipynb
# ASSIGNMENT 08.ipynb
# ASSIGNMENT 09.ipynb
# ASSIGNMENT 10.ipynb
# ASSIGNMENT 11.ipynb
# ASSIGNMENT 12.ipynb
# ASSIGNMENT 13.ipynb
# ASSIGNMENT 14.ipynb
# ASSIGNMENT 15.ipynb
# ASSIGNMENT 16.ipynb
# ASSIGNMENT 17.ipynb
# ASSIGNMENT 18.ipynb
# ASSIGNMENT 19.ipynb
# ASSIGNMENT 20.ipynb
# ASSIGNMENT 21.ipynb
# ASSIGNMENT 23.ipynb
# ASSIGNMENT 24.ipynb
# ASSIGNMENT 25.ipynb
# books.csv
# books.db
# dummy.ipynb
# enumerate in python.ipynb
# except try function.ipynb
# fibonacci series.ipynb
# format strings.ipynb
# game function.ipynb
# Hypothesis_Testing.ipynb
# inch to cm.ipynb
# iNeuron practice.ipynb
# join function.ipynb
# lambda and map func.ipynb
# lambda function.ipynb
# Linear Regression Practicals.ipynb
# Linear_reg.sav
# LR pract.ipynb
# map method.ipynb
# meritable.csv
# multi level inheritance.ipynb
# my notebook.ipynb
# myfile.txt
# Naive Bayes.ipynb
# nested loop.ipynb
# NTUSER.DAT
# ntuser.dat.LOG1
# ntuser.dat.LOG2
# NTUSER.DAT{89fd22ca-4b74-11ec-90d3-c56ee460c00c}.TM.blf
# NTUSER.DAT{89fd22ca-4b74-11ec-90d3-c56ee460c00c}.TMContainer00000000000000000001.regtrans-ms
# NTUSER.DAT{89fd22ca-4b74-11ec-90d3-c56ee460c00c}.TMContainer00000000000000000002.regtrans-ms
# ntuser.ini
# numpy pract.ipynb
# oops  child class.ipynb
# oops_class _def_init_i_o.ipynb
# over riding init method.ipynb
# pandas class 2 (1) lect.ipynb
# pandas class 31 july - with task.ipynb
# pandas pract.ipynb
# Pandas Profiling.ipynb
# polymorphism.ipynb
# Practical Logistic Reg.ipynb
# Practice class function.ipynb
# practice star  print.ipynb
# Programming Assignment 01.ipynb
# Programming Assignment 02.ipynb
# Programming Assignment 03.ipynb
# Programming Assignment 04.ipynb
# pymongo.ipynb
# pymongo1.ipynb
# read the data .ipynb
# rec Linear regression part 1.ipynb
# rec Logistics regression implementation (2).ipynb
# rec Logistics regression implementation.ipynb
# Ridge,Lasso,ElasticNet self.ipynb
# sample.ipynb
# single multi and multilevel inheritance parent and child.ipynb
# sql connector via flask.ipynb
# test.text.gz
# test.txt
# today.txt
# university_records.csv
# Untitled.ipynb
# Untitled1.ipynb
# Untitled10.ipynb
# Untitled11.ipynb
# Untitled12.ipynb
# Untitled13.ipynb
# Untitled14.ipynb
# Untitled15.ipynb
# Untitled16.ipynb
# Untitled17.ipynb
# Untitled18.ipynb
# Untitled19.ipynb
# Untitled2.ipynb
# Untitled20.ipynb
# Untitled21.ipynb
# Untitled22.ipynb
# Untitled23.ipynb
# Untitled24.ipynb
# Untitled25.ipynb
# Untitled26.ipynb
# Untitled3.ipynb
# Untitled4.ipynb
# Untitled5.ipynb
# Untitled6.ipynb
# Untitled7.ipynb
# Untitled8.ipynb
# Untitled9.ipynb
# _netrc
# anaconda-navigator.ini
# navigator.lock
# navigator.pid
# content.json
# events.json
# videos.json
# webinars.json
# defaults-2.0.0.ini
# navigator.log
# metadata.json
# navigator_updater.log
# anaconda-navigator-app-err-1.txt
# anaconda-navigator-app-out-1.txt
# anaconda-navigator-app.bat
# environments.txt
# config.yaml
# .config
# 22.Assignment_22-checkpoint.ipynb
# ALL   Practive-checkpoint.ipynb
# ASDFHJK-checkpoint.ipynb
# ASSIGNMENT 01-checkpoint.ipynb
# ASSIGNMENT 02-checkpoint.ipynb
# ASSIGNMENT 03-checkpoint.ipynb
# ASSIGNMENT 04-checkpoint.ipynb
# ASSIGNMENT 05-checkpoint.ipynb
# ASSIGNMENT 06-checkpoint.ipynb
# ASSIGNMENT 07-checkpoint.ipynb
# ASSIGNMENT 08-checkpoint.ipynb
# ASSIGNMENT 09-checkpoint.ipynb
# ASSIGNMENT 10-checkpoint.ipynb
# ASSIGNMENT 11-checkpoint.ipynb
# ASSIGNMENT 12-checkpoint.ipynb
# ASSIGNMENT 13-checkpoint.ipynb
# ASSIGNMENT 14-checkpoint.ipynb
# ASSIGNMENT 15-checkpoint.ipynb
# ASSIGNMENT 16-checkpoint.ipynb
# ASSIGNMENT 17-checkpoint.ipynb
# ASSIGNMENT 18-checkpoint.ipynb
# ASSIGNMENT 19-checkpoint.ipynb
# ASSIGNMENT 20-checkpoint.ipynb
# ASSIGNMENT 21-checkpoint.ipynb
# ASSIGNMENT 23-checkpoint.ipynb
# ASSIGNMENT 24-checkpoint.ipynb
# ASSIGNMENT 25-checkpoint.ipynb
# dummy-checkpoint.ipynb
# enumerate in python-checkpoint.ipynb
# except try function-checkpoint.ipynb
# fibonacci series-checkpoint.ipynb
# format strings-checkpoint.ipynb
# game function-checkpoint.ipynb
# Hypothesis_Testing-checkpoint.ipynb
# inch to cm-checkpoint.ipynb
# iNeuron practice-checkpoint.ipynb
# join function-checkpoint.ipynb
# lambda and map func-checkpoint.ipynb
# lambda function-checkpoint.ipynb
# LR pract-checkpoint.ipynb
# map method-checkpoint.ipynb
# multi level inheritance-checkpoint.ipynb
# my notebook-checkpoint.ipynb
# Naive Bayes-checkpoint.ipynb
# nested loop-checkpoint.ipynb
# numpy pract-checkpoint.ipynb
# oops  child class-checkpoint.ipynb
# oops_class _def_init_i_o-checkpoint.ipynb
# over riding init method-checkpoint.ipynb
# pandas class 2 (1) lect-checkpoint.ipynb
# pandas pract-checkpoint.ipynb
# Pandas Profiling-checkpoint.ipynb
# polymorphism-checkpoint.ipynb
# Practical Logistic Reg-checkpoint.ipynb
# Practice class function-checkpoint.ipynb
# practice star  print-checkpoint.ipynb
# Programming Assignment 01-checkpoint.ipynb
# Programming Assignment 02-checkpoint.ipynb
# Programming Assignment 03-checkpoint.ipynb
# Programming Assignment 04-checkpoint.ipynb
# pymongo-checkpoint.ipynb
# pymongo1-checkpoint.ipynb
# read the data -checkpoint.ipynb
# rec Linear regression part 1-checkpoint.ipynb
# rec Logistics regression implementation (2)-checkpoint.ipynb
# rec Logistics regression implementation-checkpoint.ipynb
# Ridge,Lasso,ElasticNet self-checkpoint.ipynb
# sample-checkpoint.ipynb
# single multi and multilevel inheritance parent and child-checkpoint.ipynb
# sql connector via flask-checkpoint.ipynb
# Untitled-checkpoint.ipynb
# Untitled1-checkpoint.ipynb
# Untitled10-checkpoint.ipynb
# Untitled11-checkpoint.ipynb
# Untitled12-checkpoint.ipynb
# Untitled13-checkpoint.ipynb
# Untitled14-checkpoint.ipynb
# Untitled15-checkpoint.ipynb
# Untitled16-checkpoint.ipynb
# Untitled17-checkpoint.ipynb
# Untitled18-checkpoint.ipynb
# Untitled19-checkpoint.ipynb
# Untitled2-checkpoint.ipynb
# Untitled20-checkpoint.ipynb
# Untitled21-checkpoint.ipynb
# Untitled22-checkpoint.ipynb
# Untitled23-checkpoint.ipynb
# Untitled24-checkpoint.ipynb
# Untitled25-checkpoint.ipynb
# Untitled26-checkpoint.ipynb
# Untitled3-checkpoint.ipynb
# Untitled4-checkpoint.ipynb
# Untitled5-checkpoint.ipynb
# Untitled55-checkpoint.ipynb
# Untitled56-checkpoint.ipynb
# Untitled57-checkpoint.ipynb
# Untitled58-checkpoint.ipynb
# Untitled59-checkpoint.ipynb
# Untitled6-checkpoint.ipynb
# Untitled7-checkpoint.ipynb
# Untitled8-checkpoint.ipynb
# Untitled9-checkpoint.ipynb
# history.sqlite
# README
# migrated
# edit.json
# notebook.json
# fontlist-v330.json
# anil1.stats
# main1.stats
# myfirstfile1.stats
# mypj.urls1.stats
# test1.stats
# testcode1.stats
# thehisar.urls1.stats
# help
# history.py
# history_internal.py
# langconfig
# onlinehelp
# pdb_history.sqlite
# temp.py
# template.py
# workingdir
# spyder.ini
# transient.ini
# defaults-spyder-70.1.0.ini
# defaults-transient-70.1.0.ini
# symlink
# argv.json
# .obsolete
# .vsixmanifest
# .vsixmanifest
# CHANGELOG.md
# language-configuration.json
# LICENSE.txt
# package.json
# README.md
# FUNDING.yml
# classes.toml
# imports.toml
# options.toml
# classes.toml
# fields-postgres.toml
# fields.toml
# imports.toml
# methods.toml
# classes.toml
# fields-postgres.toml
# fields.toml
# imports.toml
# managers.toml
# methods.toml
# migrations.toml
# imports.toml
# utils.toml
# imports.toml
# methods.toml
# imports.toml
# methods.toml
# regexes.toml
# classes.toml
# imports.toml
# methods.toml
# vscode-django-icon.png
# vscode-django-icon.svg
# vscode-django-syntax-gruvbox.png
# vscode-django-syntax-monokai.png
# inherits.js
# inherits_browser.js
# LICENSE
# package.json
# README.md
# .npmignore
# LICENSE
# package.json
# path.js
# README.md
# .eslintrc
# browser.js
# index.js
# LICENSE
# package.json
# README.md
# test.js
# .jshintrc
# .travis.yml
# benchmark.js
# CHANGELOG.md
# index.js
# LICENSE
# package.json
# README.md
# compiler.js
# parser.js
# toml.pegjs
# bad.toml
# example.toml
# hard_example.toml
# inline_tables.toml
# literal_strings.toml
# multiline_eat_whitespace.toml
# multiline_literal_strings.toml
# multiline_strings.toml
# smoke.js
# table_arrays_easy.toml
# table_arrays_hard.toml
# test_toml.js
# LICENSE
# package.json
# README.md
# util.js
# inherits.js
# inherits_browser.js
# LICENSE
# package.json
# README.md
# isBuffer.js
# isBufferBrowser.js
# constants.js
# extension-web.js
# extension.js
# utils.js
# base.js
# completionItemProvider.js
# definitionProvider.js
# filters.json
# tags.json
# build.py
# django-html.tmLanguage.json
# django-html.toml
# django-txt.tmLanguage.json
# django-txt.toml
# django-stuff.toml
# django-template-filter.toml
# django-template-tag-contrib.toml
# django-template-tag.toml
# entities.toml
# string-double-quoted.toml
# string-single-quoted.toml
# tag-generic-attribute.toml
# tag-id-attribute.toml
# tag-stuff.toml
# .vsixmanifest
# icon.png
# package.json
# README.md
# django-snippets.json
# .eslintignore
# .vsixmanifest
# cgmanifest.json
# CHANGELOG.md
# icon.png
# LICENSE.txt
# package.json
# package.nls.json
# README.md
# requirements.txt
# SECURITY.md
# SUPPORT.md
# test-results.xml
# ThirdPartyNotices-Distribution.txt
# ThirdPartyNotices-Repository.txt
# devcontainer.json
# Dockerfile
# extension.browser.js
# addIcon.PNG
# codeIcon.PNG
# dataViewerIcon.PNG
# exportIcon.PNG
# markdownIcon.PNG
# playIcon.PNG
# plotViewerIcon.PNG
# variableExplorerIcon.PNG
# pip-requirements.json
# extension.js
# extension.js.LICENSE.txt
# extension.js.map.disabled
# package.json
# diff-match-patch.js
# node-stream-zip.js
# node-stream-zip.js.LICENSE.txt
# request-progress.js
# request.js
# request.js.LICENSE.txt
# source-map-support.js
# sudo-prompt.js
# xml2js.js
# xml2js.js.LICENSE.txt
# Ll.js
# Lm.js
# Lo.js
# Lt.js
# Lu.js
# Mc.js
# Mn.js
# Nd.js
# Nl.js
# Pc.js
# .env
# get-pip.py
# get_output_via_markers.py
# install_debugpy.py
# interpreterInfo.py
# linter.py
# normalizeSelection.py
# Notebooks intro.ipynb
# printEnvVariables.py
# printEnvVariablesToFile.py
# pyproject.toml
# run-jedi-language-server.py
# shell_exec.py
# sortImports.py
# tensorboard_launcher.py
# testlauncher.py
# visualstudio_py_testlauncher.py
# settings.json
# README.md
# typing_extensions.py
# zipp.py
# jedi-language-server
# py.typed
# rst.py
# __init__.py
# py.typed
# _collections.py
# _compat.py
# _functools.py
# _itertools.py
# __init__.py
# cache.py
# common.py
# debug.py
# file_io.py
# parser_utils.py
# settings.py
# utils.py
# _compatibility.py
# __init__.py
# __main__.py
# classes.py
# completion.py
# completion_cache.py
# environment.py
# errors.py
# exceptions.py
# file_name.py
# helpers.py
# interpreter.py
# keywords.py
# project.py
# replstartup.py
# strings.py
# __init__.py
# extract.py
# __init__.py
# analysis.py
# arguments.py
# base_value.py
# cache.py
# context.py
# docstrings.py
# dynamic_params.py
# filters.py
# finder.py
# flow_analysis.py
# helpers.py
# imports.py
# lazy_value.py
# names.py
# param.py
# parser_cache.py
# recursion.py
# references.py
# signature.py
# star_args.py
# syntax_tree.py
# sys_path.py
# utils.py
# __init__.py
# access.py
# getattr_static.py
# mixed.py
# value.py
# __init__.py
# functions.py
# __init__.py
# __main__.py
# annotation.py
# base.py
# conversion.py
# generics.py
# stub_value.py
# typeshed.py
# type_var.py
# typing.py
# utils.py
# __init__.py
# decorator.py
# dynamic_arrays.py
# function.py
# instance.py
# iterable.py
# klass.py
# module.py
# namespace.py
# __init__.py
# django.py
# flask.py
# pytest.py
# registry.py
# stdlib.py
# __init__.py
# LICENSE.txt
# shortcuts.pyi
# __init__.pyi
# config.pyi
# registry.pyi
# __init__.pyi
# global_settings.pyi
# __init__.pyi
# __init__.pyi
# i18n.pyi
# static.pyi
# __init__.pyi
# __init__.pyi
# actions.pyi
# apps.pyi
# checks.pyi
# decorators.pyi
# filters.pyi
# forms.pyi
# helpers.pyi
# models.pyi
# options.pyi
# sites.pyi
# tests.pyi
# utils.pyi
# widgets.pyi
# __init__.pyi
# admin_list.pyi
# admin_modify.pyi
# admin_static.pyi
# admin_urls.pyi
# base.pyi
# log.pyi
# __init__.pyi
# autocomplete.pyi
# decorators.pyi
# main.pyi
# __init__.pyi
# middleware.pyi
# urls.pyi
# utils.pyi
# views.pyi
# __init__.pyi
# admin.pyi
# apps.pyi
# backends.pyi
# base_user.pyi
# checks.pyi
# context_processors.pyi
# decorators.pyi
# forms.pyi
# hashers.pyi
# middleware.pyi
# mixins.pyi
# models.pyi
# password_validation.pyi
# signals.pyi
# tokens.pyi
# urls.pyi
# validators.pyi
# views.pyi
# __init__.pyi
# modwsgi.pyi
# __init__.pyi
# __init__.pyi
# changepassword.pyi
# createsuperuser.pyi
# __init__.pyi
# admin.pyi
# apps.pyi
# checks.pyi
# fields.pyi
# forms.pyi
# models.pyi
# views.pyi
# __init__.pyi
# __init__.pyi
# remove_stale_contenttypes.pyi
# __init__.pyi
# forms.pyi
# middleware.pyi
# models.pyi
# sitemaps.pyi
# urls.pyi
# views.pyi
# __init__.pyi
# flatpages.pyi
# __init__.pyi
# __init__.pyi
# __init__.pyi
# fields.pyi
# __init__.pyi
# __init__.pyi
# humanize.pyi
# __init__.pyi
# api.pyi
# constants.pyi
# context_processors.pyi
# middleware.pyi
# utils.pyi
# views.pyi
# __init__.pyi
# base.pyi
# cookie.pyi
# fallback.pyi
# session.pyi
# __init__.pyi
# constraints.pyi
# functions.pyi
# indexes.pyi
# lookups.pyi
# operations.pyi
# search.pyi
# signals.pyi
# validators.pyi
# __init__.pyi
# general.pyi
# mixins.pyi
# statistics.pyi
# __init__.pyi
# array.pyi
# citext.pyi
# hstore.pyi
# jsonb.pyi
# mixins.pyi
# ranges.pyi
# __init__.pyi
# middleware.pyi
# models.pyi
# __init__.pyi
# base_session.pyi
# exceptions.pyi
# middleware.pyi
# models.pyi
# serializers.pyi
# __init__.pyi
# base.pyi
# cache.pyi
# cached_db.pyi
# db.pyi
# file.pyi
# signed_cookies.pyi
# __init__.pyi
# __init__.pyi
# clearsessions.pyi
# __init__.pyi
# views.pyi
# __init__.pyi
# __init__.pyi
# ping_google.pyi
# __init__.pyi
# apps.pyi
# management.pyi
# managers.pyi
# middleware.pyi
# models.pyi
# requests.pyi
# shortcuts.pyi
# __init__.pyi
# apps.pyi
# checks.pyi
# finders.pyi
# handlers.pyi
# storage.pyi
# testing.pyi
# urls.pyi
# utils.pyi
# views.pyi
# __init__.pyi
# __init__.pyi
# collectstatic.pyi
# findstatic.pyi
# runserver.pyi
# __init__.pyi
# staticfiles.pyi
# __init__.pyi
# views.pyi
# __init__.pyi
# exceptions.pyi
# paginator.pyi
# signals.pyi
# signing.pyi
# validators.pyi
# wsgi.pyi
# __init__.pyi
# utils.pyi
# __init__.pyi
# base.pyi
# db.pyi
# dummy.pyi
# filebased.pyi
# locmem.pyi
# memcached.pyi
# __init__.pyi
# caches.pyi
# database.pyi
# messages.pyi
# model_checks.pyi
# registry.pyi
# templates.pyi
# translation.pyi
# urls.pyi
# __init__.pyi
# base.pyi
# csrf.pyi
# sessions.pyi
# __init__.pyi
# base.pyi
# images.pyi
# locks.pyi
# move.pyi
# storage.pyi
# temp.pyi
# uploadedfile.pyi
# uploadhandler.pyi
# utils.pyi
# __init__.pyi
# base.pyi
# exception.pyi
# wsgi.pyi
# __init__.pyi
# message.pyi
# utils.pyi
# __init__.pyi
# base.pyi
# console.pyi
# dummy.pyi
# filebased.pyi
# locmem.pyi
# smtp.pyi
# __init__.pyi
# base.pyi
# color.pyi
# sql.pyi
# templates.pyi
# utils.pyi
# __init__.pyi
# dumpdata.pyi
# loaddata.pyi
# makemessages.pyi
# runserver.pyi
# testserver.pyi
# __init__.pyi
# base.pyi
# json.pyi
# python.pyi
# __init__.pyi
# basehttp.pyi
# __init__.pyi
# transaction.pyi
# utils.pyi
# __init__.pyi
# ddl_references.pyi
# signals.pyi
# utils.pyi
# __init__.pyi
# base.pyi
# client.pyi
# creation.pyi
# features.pyi
# introspection.pyi
# operations.pyi
# schema.pyi
# validation.pyi
# __init__.pyi
# base.pyi
# __init__.pyi
# client.pyi
# __init__.pyi
# base.pyi
# client.pyi
# creation.pyi
# operations.pyi
# __init__.pyi
# base.pyi
# creation.pyi
# features.pyi
# introspection.pyi
# operations.pyi
# schema.pyi
# __init__.pyi
# autodetector.pyi
# exceptions.pyi
# executor.pyi
# graph.pyi
# loader.pyi
# migration.pyi
# optimizer.pyi
# questioner.pyi
# recorder.pyi
# serializer.pyi
# state.pyi
# topological_sort.pyi
# utils.pyi
# writer.pyi
# __init__.pyi
# base.pyi
# fields.pyi
# models.pyi
# special.pyi
# utils.pyi
# __init__.pyi
# aggregates.pyi
# base.pyi
# constraints.pyi
# deletion.pyi
# enums.pyi
# expressions.pyi
# indexes.pyi
# lookups.pyi
# manager.pyi
# options.pyi
# query.pyi
# query_utils.pyi
# signals.pyi
# utils.pyi
# __init__.pyi
# files.pyi
# mixins.pyi
# proxy.pyi
# related.pyi
# related_descriptors.pyi
# related_lookups.pyi
# reverse_related.pyi
# __init__.pyi
# comparison.pyi
# datetime.pyi
# math.pyi
# mixins.pyi
# text.pyi
# window.pyi
# __init__.pyi
# compiler.pyi
# constants.pyi
# datastructures.pyi
# query.pyi
# subqueries.pyi
# where.pyi
# __init__.pyi
# dispatcher.pyi
# __init__.pyi
# boundfield.pyi
# fields.pyi
# forms.pyi
# formsets.pyi
# models.pyi
# renderers.pyi
# utils.pyi
# widgets.pyi
# __init__.pyi
# cookie.pyi
# multipartparser.pyi
# request.pyi
# response.pyi
# __init__.pyi
# cache.pyi
# clickjacking.pyi
# common.pyi
# csrf.pyi
# gzip.pyi
# http.pyi
# locale.pyi
# security.pyi
# __init__.pyi
# base.pyi
# context.pyi
# context_processors.pyi
# defaultfilters.pyi
# defaulttags.pyi
# engine.pyi
# exceptions.pyi
# library.pyi
# loader.pyi
# loader_tags.pyi
# response.pyi
# smartif.pyi
# utils.pyi
# __init__.pyi
# base.pyi
# django.pyi
# dummy.pyi
# jinja2.pyi
# utils.pyi
# __init__.pyi
# app_directories.pyi
# base.pyi
# cached.pyi
# filesystem.pyi
# locmem.pyi
# __init__.pyi
# cache.pyi
# i18n.pyi
# l10n.pyi
# static.pyi
# tz.pyi
# __init__.pyi
# client.pyi
# html.pyi
# runner.pyi
# selenium.pyi
# signals.pyi
# testcases.pyi
# utils.pyi
# __init__.pyi
# base.pyi
# conf.pyi
# converters.pyi
# exceptions.pyi
# resolvers.pyi
# utils.pyi
# __init__.pyi
# archive.pyi
# autoreload.pyi
# baseconv.pyi
# cache.pyi
# crypto.pyi
# datastructures.pyi
# dateformat.pyi
# dateparse.pyi
# dates.pyi
# datetime_safe.pyi
# deconstruct.pyi
# decorators.pyi
# deprecation.pyi
# duration.pyi
# encoding.pyi
# feedgenerator.pyi
# formats.pyi
# functional.pyi
# hashable.pyi
# html.pyi
# http.pyi
# inspect.pyi
# ipv6.pyi
# itercompat.pyi
# jslex.pyi
# log.pyi
# lorem_ipsum.pyi
# module_loading.pyi
# numberformat.pyi
# regex_helper.pyi
# safestring.pyi
# six.pyi
# termcolors.pyi
# text.pyi
# timesince.pyi
# timezone.pyi
# topological_sort.pyi
# tree.pyi
# version.pyi
# xmlutils.pyi
# _os.pyi
# __init__.pyi
# reloader.pyi
# template.pyi
# trans_null.pyi
# trans_real.pyi
# __init__.pyi
# csrf.pyi
# debug.pyi
# defaults.pyi
# i18n.pyi
# static.pyi
# __init__.pyi
# cache.pyi
# clickjacking.pyi
# csrf.pyi
# debug.pyi
# gzip.pyi
# http.pyi
# vary.pyi
# __init__.pyi
# base.pyi
# dates.pyi
# detail.pyi
# edit.pyi
# list.pyi
# __init__.pyi
# LICENSE
# abc.pyi
# ast.pyi
# atexit.pyi
# BaseHTTPServer.pyi
# CGIHTTPServer.pyi
# collections.pyi
# commands.pyi
# compileall.pyi
# ConfigParser.pyi
# Cookie.pyi
# cookielib.pyi
# copy_reg.pyi
# cPickle.pyi
# cStringIO.pyi
# dircache.pyi
# dummy_thread.pyi
# exceptions.pyi
# fcntl.pyi
# fnmatch.pyi
# functools.pyi
# future_builtins.pyi
# gc.pyi
# getopt.pyi
# getpass.pyi
# gettext.pyi
# glob.pyi
# gzip.pyi
# hashlib.pyi
# heapq.pyi
# htmlentitydefs.pyi
# HTMLParser.pyi
# httplib.pyi
# imp.pyi
# importlib.pyi
# inspect.pyi
# io.pyi
# itertools.pyi
# json.pyi
# markupbase.pyi
# md5.pyi
# mimetools.pyi
# mutex.pyi
# nturl2path.pyi
# os2emxpath.pyi
# pipes.pyi
# platform.pyi
# popen2.pyi
# posix.pyi
# Queue.pyi
# random.pyi
# re.pyi
# repr.pyi
# resource.pyi
# rfc822.pyi
# robotparser.pyi
# runpy.pyi
# sets.pyi
# sha.pyi
# shelve.pyi
# shlex.pyi
# signal.pyi
# SimpleHTTPServer.pyi
# smtplib.pyi
# SocketServer.pyi
# spwd.pyi
# sre_constants.pyi
# sre_parse.pyi
# stat.pyi
# string.pyi
# StringIO.pyi
# stringold.pyi
# strop.pyi
# subprocess.pyi
# symbol.pyi
# sys.pyi
# tempfile.pyi
# textwrap.pyi
# thread.pyi
# toaiff.pyi
# tokenize.pyi
# types.pyi
# typing.pyi
# unittest.pyi
# urllib.pyi
# urllib2.pyi
# urlparse.pyi
# user.pyi
# UserDict.pyi
# UserList.pyi
# UserString.pyi
# whichdb.pyi
# xmlrpclib.pyi
# _ast.pyi
# _collections.pyi
# _functools.pyi
# _hotshot.pyi
# _io.pyi
# _json.pyi
# _md5.pyi
# _sha.pyi
# _sha256.pyi
# _sha512.pyi
# _socket.pyi
# _sre.pyi
# _struct.pyi
# _symtable.pyi
# _threading_local.pyi
# __builtin__.pyi
# emxccompiler.pyi
# __init__.pyi
# base64mime.pyi
# charset.pyi
# encoders.pyi
# feedparser.pyi
# generator.pyi
# header.pyi
# iterators.pyi
# message.pyi
# MIMEText.pyi
# parser.pyi
# quoprimime.pyi
# utils.pyi
# _parseaddr.pyi
# __init__.pyi
# application.pyi
# audio.pyi
# base.pyi
# image.pyi
# message.pyi
# multipart.pyi
# nonmultipart.pyi
# text.pyi
# __init__.pyi
# utf_8.pyi
# __init__.pyi
# pool.pyi
# process.pyi
# util.pyi
# __init__.pyi
# connection.pyi
# __init__.pyi
# path.pyi
# __init__.pyi
# aifc.pyi
# argparse.pyi
# array.pyi
# asynchat.pyi
# asyncore.pyi
# audioop.pyi
# base64.pyi
# bdb.pyi
# binascii.pyi
# binhex.pyi
# bisect.pyi
# builtins.pyi
# bz2.pyi
# calendar.pyi
# cgi.pyi
# cgitb.pyi
# chunk.pyi
# cmath.pyi
# cmd.pyi
# code.pyi
# codecs.pyi
# codeop.pyi
# colorsys.pyi
# contextlib.pyi
# copy.pyi
# cProfile.pyi
# crypt.pyi
# csv.pyi
# datetime.pyi
# decimal.pyi
# difflib.pyi
# dis.pyi
# doctest.pyi
# errno.pyi
# filecmp.pyi
# fileinput.pyi
# formatter.pyi
# fractions.pyi
# ftplib.pyi
# genericpath.pyi
# grp.pyi
# hmac.pyi
# imaplib.pyi
# imghdr.pyi
# keyword.pyi
# linecache.pyi
# locale.pyi
# macpath.pyi
# mailbox.pyi
# mailcap.pyi
# marshal.pyi
# math.pyi
# mimetypes.pyi
# mmap.pyi
# modulefinder.pyi
# netrc.pyi
# nis.pyi
# ntpath.pyi
# numbers.pyi
# opcode.pyi
# operator.pyi
# optparse.pyi
# pdb.pyi
# pickle.pyi
# pickletools.pyi
# pkgutil.pyi
# plistlib.pyi
# poplib.pyi
# posixpath.pyi
# pprint.pyi
# profile.pyi
# pstats.pyi
# pty.pyi
# pwd.pyi
# pyclbr.pyi
# pydoc.pyi
# py_compile.pyi
# quopri.pyi
# readline.pyi
# rlcompleter.pyi
# sched.pyi
# select.pyi
# shutil.pyi
# site.pyi
# smtpd.pyi
# sndhdr.pyi
# socket.pyi
# sre_compile.pyi
# ssl.pyi
# stringprep.pyi
# struct.pyi
# sunau.pyi
# symtable.pyi
# sysconfig.pyi
# syslog.pyi
# tabnanny.pyi
# tarfile.pyi
# telnetlib.pyi
# termios.pyi
# threading.pyi
# time.pyi
# timeit.pyi
# token.pyi
# trace.pyi
# traceback.pyi
# tty.pyi
# turtle.pyi
# unicodedata.pyi
# uu.pyi
# uuid.pyi
# warnings.pyi
# wave.pyi
# weakref.pyi
# webbrowser.pyi
# xdrlib.pyi
# zipfile.pyi
# zipimport.pyi
# zlib.pyi
# _bisect.pyi
# _codecs.pyi
# _csv.pyi
# _curses.pyi
# _heapq.pyi
# _random.pyi
# _warnings.pyi
# _weakref.pyi
# _weakrefset.pyi
# __future__.pyi
# util.pyi
# wintypes.pyi
# __init__.pyi
# ascii.pyi
# panel.pyi
# textpad.pyi
# __init__.pyi
# archive_util.pyi
# bcppcompiler.pyi
# ccompiler.pyi
# cmd.pyi
# core.pyi
# cygwinccompiler.pyi
# debug.pyi
# dep_util.pyi
# dir_util.pyi
# dist.pyi
# errors.pyi
# extension.pyi
# fancy_getopt.pyi
# filelist.pyi
# file_util.pyi
# log.pyi
# msvccompiler.pyi
# spawn.pyi
# sysconfig.pyi
# text_file.pyi
# unixccompiler.pyi
# util.pyi
# version.pyi
# __init__.pyi
# bdist.pyi
# bdist_dumb.pyi
# bdist_msi.pyi
# bdist_packager.pyi
# bdist_rpm.pyi
# bdist_wininst.pyi
# build.pyi
# build_clib.pyi
# build_ext.pyi
# build_py.pyi
# build_scripts.pyi
# check.pyi
# clean.pyi
# config.pyi
# install.pyi
# install_data.pyi
# install_headers.pyi
# install_lib.pyi
# install_scripts.pyi
# register.pyi
# sdist.pyi
# __init__.pyi
# __init__.pyi
# pygram.pyi
# pytree.pyi
# __init__.pyi
# driver.pyi
# grammar.pyi
# literals.pyi
# parse.pyi
# pgen.pyi
# token.pyi
# tokenize.pyi
# __init__.pyi
# config.pyi
# handlers.pyi
# __init__.pyi
# errors.pyi
# model.pyi
# __init__.pyi
# dbapi2.pyi
# __init__.pyi
# handlers.pyi
# headers.pyi
# simple_server.pyi
# types.pyi
# util.pyi
# validate.pyi
# __init__.pyi
# __init__.pyi
# cElementTree.pyi
# ElementInclude.pyi
# ElementPath.pyi
# ElementTree.pyi
# __init__.pyi
# __init__.pyi
# errors.pyi
# model.pyi
# __init__.pyi
# handler.pyi
# saxutils.pyi
# xmlreader.pyi
# __init__.pyi
# abc.pyi
# ast.pyi
# atexit.pyi
# compileall.pyi
# configparser.pyi
# copyreg.pyi
# enum.pyi
# faulthandler.pyi
# fcntl.pyi
# fnmatch.pyi
# functools.pyi
# gc.pyi
# getopt.pyi
# getpass.pyi
# gettext.pyi
# glob.pyi
# gzip.pyi
# hashlib.pyi
# heapq.pyi
# imp.pyi
# inspect.pyi
# io.pyi
# ipaddress.pyi
# itertools.pyi
# lzma.pyi
# msvcrt.pyi
# nntplib.pyi
# nturl2path.pyi
# pathlib.pyi
# pipes.pyi
# platform.pyi
# posix.pyi
# queue.pyi
# random.pyi
# re.pyi
# reprlib.pyi
# resource.pyi
# runpy.pyi
# selectors.pyi
# shelve.pyi
# shlex.pyi
# signal.pyi
# smtplib.pyi
# socketserver.pyi
# spwd.pyi
# sre_constants.pyi
# sre_parse.pyi
# stat.pyi
# statistics.pyi
# string.pyi
# subprocess.pyi
# symbol.pyi
# sys.pyi
# tempfile.pyi
# textwrap.pyi
# tokenize.pyi
# tracemalloc.pyi
# types.pyi
# typing.pyi
# zipapp.pyi
# _ast.pyi
# _compression.pyi
# _dummy_thread.pyi
# _imp.pyi
# _importlib_modulespec.pyi
# _json.pyi
# _markupbase.pyi
# _operator.pyi
# _posixsubprocess.pyi
# _stat.pyi
# _subprocess.pyi
# _thread.pyi
# _threading_local.pyi
# _tracemalloc.pyi
# _winapi.pyi
# base_events.pyi
# constants.pyi
# coroutines.pyi
# events.pyi
# exceptions.pyi
# futures.pyi
# locks.pyi
# proactor_events.pyi
# protocols.pyi
# queues.pyi
# runners.pyi
# selector_events.pyi
# streams.pyi
# subprocess.pyi
# tasks.pyi
# transports.pyi
# windows_events.pyi
# windows_utils.pyi
# __init__.pyi
# abc.pyi
# __init__.pyi
# __init__.pyi
# process.pyi
# thread.pyi
# _base.pyi
# __init__.pyi
# charset.pyi
# contentmanager.pyi
# encoders.pyi
# errors.pyi
# feedparser.pyi
# generator.pyi
# header.pyi
# headerregistry.pyi
# iterators.pyi
# message.pyi
# parser.pyi
# policy.pyi
# utils.pyi
# __init__.pyi
# application.pyi
# audio.pyi
# base.pyi
# image.pyi
# message.pyi
# multipart.pyi
# nonmultipart.pyi
# text.pyi
# __init__.pyi
# utf_8.pyi
# __init__.pyi
# entities.pyi
# parser.pyi
# __init__.pyi
# client.pyi
# cookiejar.pyi
# cookies.pyi
# server.pyi
# __init__.pyi
# abc.pyi
# machinery.pyi
# metadata.pyi
# resources.pyi
# util.pyi
# __init__.pyi
# decoder.pyi
# encoder.pyi
# __init__.pyi
# connection.pyi
# context.pyi
# managers.pyi
# pool.pyi
# process.pyi
# queues.pyi
# shared_memory.pyi
# spawn.pyi
# synchronize.pyi
# __init__.pyi
# connection.pyi
# __init__.pyi
# path.pyi
# __init__.pyi
# commondialog.pyi
# constants.pyi
# dialog.pyi
# filedialog.pyi
# messagebox.pyi
# ttk.pyi
# __init__.pyi
# async_case.pyi
# case.pyi
# loader.pyi
# mock.pyi
# result.pyi
# runner.pyi
# signals.pyi
# suite.pyi
# util.pyi
# __init__.pyi
# error.pyi
# parse.pyi
# request.pyi
# response.pyi
# robotparser.pyi
# __init__.pyi
# secrets.pyi
# contextvars.pyi
# dataclasses.pyi
# enum.pyi
# gflags.pyi
# ipaddress.pyi
# pathlib2.pyi
# pymssql.pyi
# __init__.pyi
# process.pyi
# thread.pyi
# _base.pyi
# __init__.pyi
# FacebookService.pyi
# __init__.pyi
# client.pyi
# exceptions.pyi
# __init__.pyi
# watchers.pyi
# __init__.pyi
# crypto.pyi
# __init__.pyi
# mapper.pyi
# util.pyi
# __init__.pyi
# scribe.pyi
# ttypes.pyi
# __init__.pyi
# __init__.pyi
# BaseHTTPServer.pyi
# CGIHTTPServer.pyi
# configparser.pyi
# cPickle.pyi
# email_mime_base.pyi
# email_mime_multipart.pyi
# email_mime_nonmultipart.pyi
# email_mime_text.pyi
# html_entities.pyi
# html_parser.pyi
# http_client.pyi
# http_cookiejar.pyi
# http_cookies.pyi
# queue.pyi
# reprlib.pyi
# SimpleHTTPServer.pyi
# socketserver.pyi
# urllib_error.pyi
# urllib_parse.pyi
# urllib_request.pyi
# urllib_response.pyi
# urllib_robotparser.pyi
# xmlrpc_client.pyi
# _dummy_thread.pyi
# _thread.pyi
# __init__.pyi
# error.pyi
# parse.pyi
# request.pyi
# response.pyi
# robotparser.pyi
# __init__.pyi
# concurrent.pyi
# gen.pyi
# httpclient.pyi
# httpserver.pyi
# httputil.pyi
# ioloop.pyi
# locks.pyi
# netutil.pyi
# process.pyi
# tcpserver.pyi
# testing.pyi
# util.pyi
# web.pyi
# __init__.pyi
# backports_abc.pyi
# certifi.pyi
# croniter.pyi
# decorator.pyi
# emoji.pyi
# first.pyi
# itsdangerous.pyi
# mock.pyi
# mypy_extensions.pyi
# pycurl.pyi
# pyre_extensions.pyi
# singledispatch.pyi
# tabulate.pyi
# termcolor.pyi
# toml.pyi
# typing_extensions.pyi
# ujson.pyi
# __init__.pyi
# converters.pyi
# exceptions.pyi
# filters.pyi
# validators.pyi
# __init__.pyi
# ssl_match_hostname.pyi
# __init__.pyi
# callbacks.pyi
# linkifier.pyi
# sanitizer.pyi
# utils.pyi
# __init__.pyi
# auth.pyi
# auth_handler.pyi
# compat.pyi
# connection.pyi
# exception.pyi
# plugin.pyi
# regioninfo.pyi
# utils.pyi
# __init__.pyi
# __init__.pyi
# __init__.pyi
# exceptions.pyi
# layer1.pyi
# __init__.pyi
# acl.pyi
# bucket.pyi
# bucketlistresultset.pyi
# bucketlogging.pyi
# connection.pyi
# cors.pyi
# deletemarker.pyi
# key.pyi
# keyfile.pyi
# lifecycle.pyi
# multidelete.pyi
# multipart.pyi
# prefix.pyi
# tagging.pyi
# user.pyi
# website.pyi
# __init__.pyi
# __init__.pyi
# core.pyi
# decorators.pyi
# exceptions.pyi
# formatting.pyi
# globals.pyi
# parser.pyi
# termui.pyi
# testing.pyi
# types.pyi
# utils.pyi
# _termui_impl.pyi
# __init__.pyi
# pct_warnings.pyi
# __init__.pyi
# AES.pyi
# ARC2.pyi
# ARC4.pyi
# blockalgo.pyi
# Blowfish.pyi
# CAST.pyi
# DES.pyi
# DES3.pyi
# PKCS1_OAEP.pyi
# PKCS1_v1_5.pyi
# XOR.pyi
# __init__.pyi
# hashalgo.pyi
# HMAC.pyi
# MD2.pyi
# MD4.pyi
# MD5.pyi
# RIPEMD.pyi
# SHA.pyi
# SHA224.pyi
# SHA256.pyi
# SHA384.pyi
# SHA512.pyi
# __init__.pyi
# AllOrNothing.pyi
# Chaffing.pyi
# KDF.pyi
# __init__.pyi
# DSA.pyi
# ElGamal.pyi
# pubkey.pyi
# RSA.pyi
# __init__.pyi
# random.pyi
# __init__.pyi
# FortunaAccumulator.pyi
# FortunaGenerator.pyi
# SHAd256.pyi
# __init__.pyi
# fallback.pyi
# posix.pyi
# rng_base.pyi
# __init__.pyi
# PKCS1_PSS.pyi
# PKCS1_v1_5.pyi
# __init__.pyi
# asn1.pyi
# Counter.pyi
# number.pyi
# randpool.pyi
# RFC1751.pyi
# strxor.pyi
# __init__.pyi
# exceptions.pyi
# fernet.pyi
# x509.pyi
# __init__.pyi
# __init__.pyi
# interfaces.pyi
# __init__.pyi
# __init__.pyi
# binding.pyi
# __init__.pyi
# cmac.pyi
# constant_time.pyi
# hashes.pyi
# hmac.pyi
# keywrap.pyi
# padding.pyi
# poly1305.pyi
# __init__.pyi
# dh.pyi
# dsa.pyi
# ec.pyi
# ed25519.pyi
# ed448.pyi
# padding.pyi
# rsa.pyi
# utils.pyi
# x25519.pyi
# x448.pyi
# __init__.pyi
# aead.pyi
# algorithms.pyi
# modes.pyi
# __init__.pyi
# concatkdf.pyi
# hkdf.pyi
# kbkdf.pyi
# pbkdf2.pyi
# scrypt.pyi
# x963kdf.pyi
# __init__.pyi
# pkcs12.pyi
# __init__.pyi
# hotp.pyi
# totp.pyi
# __init__.pyi
# parser.pyi
# relativedelta.pyi
# rrule.pyi
# utils.pyi
# _common.pyi
# __init__.pyi
# tz.pyi
# _common.pyi
# __init__.pyi
# app.pyi
# blueprints.pyi
# cli.pyi
# config.pyi
# ctx.pyi
# debughelpers.pyi
# globals.pyi
# helpers.pyi
# logging.pyi
# sessions.pyi
# signals.pyi
# templating.pyi
# testing.pyi
# views.pyi
# wrappers.pyi
# __init__.pyi
# tag.pyi
# __init__.pyi
# database.pyi
# errors.pyi
# mixins.pyi
# models.pyi
# records.pyi
# __init__.pyi
# __init__.pyi
# any_pb2.pyi
# any_test_pb2.pyi
# api_pb2.pyi
# descriptor.pyi
# descriptor_pb2.pyi
# descriptor_pool.pyi
# duration_pb2.pyi
# empty_pb2.pyi
# field_mask_pb2.pyi
# json_format.pyi
# map_proto2_unittest_pb2.pyi
# map_unittest_pb2.pyi
# message.pyi
# message_factory.pyi
# reflection.pyi
# service.pyi
# source_context_pb2.pyi
# struct_pb2.pyi
# symbol_database.pyi
# test_messages_proto2_pb2.pyi
# test_messages_proto3_pb2.pyi
# timestamp_pb2.pyi
# type_pb2.pyi
# unittest_arena_pb2.pyi
# unittest_custom_options_pb2.pyi
# unittest_import_pb2.pyi
# unittest_import_public_pb2.pyi
# unittest_mset_pb2.pyi
# unittest_mset_wire_format_pb2.pyi
# unittest_no_arena_import_pb2.pyi
# unittest_no_arena_pb2.pyi
# unittest_no_generic_services_pb2.pyi
# unittest_pb2.pyi
# unittest_proto3_arena_pb2.pyi
# wrappers_pb2.pyi
# __init__.pyi
# plugin_pb2.pyi
# __init__.pyi
# containers.pyi
# decoder.pyi
# encoder.pyi
# enum_type_wrapper.pyi
# message_listener.pyi
# well_known_types.pyi
# wire_format.pyi
# __init__.pyi
# json_format_proto3_pb2.pyi
# __init__.pyi
# bccache.pyi
# compiler.pyi
# constants.pyi
# debug.pyi
# defaults.pyi
# environment.pyi
# exceptions.pyi
# ext.pyi
# filters.pyi
# lexer.pyi
# loaders.pyi
# meta.pyi
# nodes.pyi
# optimizer.pyi
# parser.pyi
# runtime.pyi
# sandbox.pyi
# tests.pyi
# utils.pyi
# visitor.pyi
# _compat.pyi
# _stringdefs.pyi
# __init__.pyi
# _compat.pyi
# _constants.pyi
# _native.pyi
# _speedups.pyi
# __init__.pyi
# compat.pyi
# const.pyi
# decoder.pyi
# errors.pyi
# extension.pyi
# reader.pyi
# __init__.pyi
# charset.pyi
# connections.pyi
# converters.pyi
# cursors.pyi
# err.pyi
# times.pyi
# util.pyi
# __init__.pyi
# CLIENT.pyi
# COMMAND.pyi
# ER.pyi
# FIELD_TYPE.pyi
# FLAG.pyi
# SERVER_STATUS.pyi
# __init__.pyi
# attributes.pyi
# constants.pyi
# exceptions.pyi
# indexes.pyi
# models.pyi
# settings.pyi
# throttle.pyi
# types.pyi
# __init__.pyi
# base.pyi
# table.pyi
# util.pyi
# __init__.pyi
# __init__.pyi
# client.pyi
# connection.pyi
# exceptions.pyi
# utils.pyi
# __init__.pyi
# adapters.pyi
# api.pyi
# auth.pyi
# compat.pyi
# cookies.pyi
# exceptions.pyi
# hooks.pyi
# models.pyi
# sessions.pyi
# status_codes.pyi
# structures.pyi
# utils.pyi
# __init__.pyi
# __init__.pyi
# connection.pyi
# connectionpool.pyi
# exceptions.pyi
# fields.pyi
# filepost.pyi
# poolmanager.pyi
# request.pyi
# response.pyi
# _collections.pyi
# __init__.pyi
# __init__.pyi
# __init__.pyi
# _implementation.pyi
# __init__.pyi
# connection.pyi
# request.pyi
# response.pyi
# retry.pyi
# ssl_.pyi
# timeout.pyi
# url.pyi
# __init__.pyi
# decoder.pyi
# encoder.pyi
# scanner.pyi
# __init__.pyi
# datastructures.pyi
# exceptions.pyi
# filesystem.pyi
# formparser.pyi
# http.pyi
# local.pyi
# posixemulation.pyi
# routing.pyi
# script.pyi
# security.pyi
# serving.pyi
# test.pyi
# testapp.pyi
# urls.pyi
# useragents.pyi
# utils.pyi
# wrappers.pyi
# wsgi.pyi
# _compat.pyi
# _internal.pyi
# _reloader.pyi
# __init__.pyi
# atom.pyi
# cache.pyi
# fixers.pyi
# iterio.pyi
# jsrouting.pyi
# limiter.pyi
# lint.pyi
# profiler.pyi
# securecookie.pyi
# sessions.pyi
# testtools.pyi
# wrappers.pyi
# __init__.pyi
# console.pyi
# repr.pyi
# tbtools.pyi
# __init__.pyi
# dispatcher.pyi
# http_proxy.pyi
# lint.pyi
# profiler.pyi
# proxy_fix.pyi
# shared_data.pyi
# __init__.pyi
# composer.pyi
# constructor.pyi
# cyaml.pyi
# dumper.pyi
# emitter.pyi
# error.pyi
# events.pyi
# loader.pyi
# nodes.pyi
# parser.pyi
# reader.pyi
# representer.pyi
# resolver.pyi
# scanner.pyi
# serializer.pyi
# tokens.pyi
# __init__.pyi
# contextvars.pyi
# dataclasses.pyi
# orjson.pyi
# examples.pyi
# nodes.pyi
# __init__.pyi
# __init__.pyi
# nodes.pyi
# roles.pyi
# states.pyi
# __init__.pyi
# algorithms.pyi
# __init__.pyi
# __init__.pyi
# pycrypto.pyi
# py_ecdsa.pyi
# __init__.pyi
# py31compat.pyi
# __init__.pyi
# __init__.pyi
# BaseHTTPServer.pyi
# builtins.pyi
# CGIHTTPServer.pyi
# configparser.pyi
# cPickle.pyi
# email_mime_base.pyi
# email_mime_multipart.pyi
# email_mime_nonmultipart.pyi
# email_mime_text.pyi
# html_entities.pyi
# html_parser.pyi
# http_client.pyi
# http_cookiejar.pyi
# http_cookies.pyi
# queue.pyi
# reprlib.pyi
# SimpleHTTPServer.pyi
# socketserver.pyi
# tkinter.pyi
# tkinter_commondialog.pyi
# tkinter_constants.pyi
# tkinter_dialog.pyi
# tkinter_filedialog.pyi
# tkinter_tkfiledialog.pyi
# tkinter_ttk.pyi
# urllib_error.pyi
# urllib_parse.pyi
# urllib_request.pyi
# urllib_response.pyi
# urllib_robotparser.pyi
# _dummy_thread.pyi
# _thread.pyi
# __init__.pyi
# error.pyi
# parse.pyi
# request.pyi
# response.pyi
# robotparser.pyi
# __init__.pyi
# ast27.pyi
# ast3.pyi
# conversions.pyi
# __init__.pyi
# cli.py
# constants.py
# initialization_options.py
# jedi_utils.py
# py.typed
# pygls_utils.py
# server.py
# text_edit_utils.py
# type_map.py
# __init__.py
# cache.py
# file_io.py
# grammar.py
# normalizer.py
# parser.py
# py.typed
# tree.py
# utils.py
# _compatibility.py
# __init__.py
# generator.py
# grammar_parser.py
# __init__.py
# diff.py
# errors.py
# grammar310.txt
# grammar36.txt
# grammar37.txt
# grammar38.txt
# grammar39.txt
# parser.py
# pep8.py
# prefix.py
# token.py
# tokenize.py
# tree.py
# __init__.py
# annotated_types.py
# class_validators.py
# color.py
# dataclasses.py
# datetime_parse.py
# decorator.py
# env_settings.py
# errors.py
# error_wrappers.py
# fields.py
# generics.py
# json.py
# main.py
# mypy.py
# networks.py
# parse.py
# py.typed
# schema.py
# tools.py
# types.py
# typing.py
# utils.py
# validators.py
# version.py
# _hypothesis_plugin.py
# __init__.py
# capabilities.py
# constants.py
# exceptions.py
# feature_manager.py
# progress.py
# protocol.py
# py.typed
# server.py
# uris.py
# workspace.py
# __init__.py
# methods.py
# __init__.py
# basic_structures.py
# client.py
# diagnostics.py
# file_operations.py
# general_messages.py
# text_synchronization.py
# window.py
# workspace.py
# __init__.py
# call_hierarchy.py
# code_action.py
# code_lens.py
# color_presentation.py
# completion.py
# declaration.py
# definition.py
# document_color.py
# document_highlight.py
# document_link.py
# document_symbol.py
# folding_range.py
# formatting.py
# hover.py
# implementation.py
# linked_editing_range.py
# monikers.py
# on_type_formatting.py
# prepare_rename.py
# range_formatting.py
# references.py
# rename.py
# selection_range.py
# semantic_tokens.py
# signature_help.py
# type_definition.py
# __init__.py
# importhook.py
# py.typed
# pytest_plugin.py
# __init__.py
# ThirdPartyNotices.txt
# _version.py
# __init__.py
# __main__.py
# clients.py
# components.py
# launchers.py
# servers.py
# sessions.py
# __init__.py
# __main__.py
# compat.py
# fmt.py
# json.py
# log.py
# messaging.py
# modules.py
# singleton.py
# sockets.py
# stacks.py
# timestamp.py
# util.py
# __init__.py
# debuggee.py
# handlers.py
# output.py
# winapi.py
# __init__.py
# __main__.py
# api.py
# attach_pid_injected.py
# cli.py
# __init__.py
# force_pydevd.py
# _pydevd_packaging.py
# _util.py
# __init__.py
# pydevconsole.py
# pydevd.py
# pydevd_file_utils.py
# pydevd_tracing.py
# pydev_app_engine_debug_startup.py
# pydev_coverage.py
# pydev_pysrc.py
# pydev_run_in_console.py
# setup_cython.py
# add_code_to_python_process.py
# attach_amd64.dll
# attach_amd64.pdb
# attach_linux_amd64.so
# attach_pydevd.py
# attach_script.py
# attach_x86.dll
# attach_x86.pdb
# attach_x86_64.dylib
# inject_dll_amd64.exe
# inject_dll_amd64.pdb
# inject_dll_x86.exe
# inject_dll_x86.pdb
# README.txt
# run_code_on_dllmain_amd64.dll
# run_code_on_dllmain_amd64.pdb
# run_code_on_dllmain_x86.dll
# run_code_on_dllmain_x86.pdb
# _always_live_program.py
# _check.py
# _test_attach_to_process.py
# _test_attach_to_process_linux.py
# python.h
# py_custom_pyeval_settrace.hpp
# py_custom_pyeval_settrace_310.hpp
# py_custom_pyeval_settrace_common.hpp
# py_settrace.hpp
# py_utils.hpp
# py_version.hpp
# ref_utils.hpp
# .gitignore
# attach.cpp
# compile_linux.sh
# compile_mac.sh
# compile_manylinux.cmd
# lldb_prepare.py
# breakpoint.py
# compat.py
# crash.py
# debug.py
# disasm.py
# event.py
# interactive.py
# module.py
# process.py
# registry.py
# search.py
# sql.py
# system.py
# textio.py
# thread.py
# util.py
# window.py
# __init__.py
# do_example.py
# do_exchain.py
# do_exploitable.py
# do_symfix.py
# README
# __init__.py
# advapi32.py
# context_amd64.py
# context_i386.py
# dbghelp.py
# defines.py
# gdi32.py
# kernel32.py
# ntdll.py
# peb_teb.py
# psapi.py
# shell32.py
# shlwapi.py
# user32.py
# version.py
# wtsapi32.py
# __init__.py
# attach.cpp
# attach.h
# compile_windows.bat
# inject_dll.cpp
# py_win_helpers.hpp
# run_code_in_memory.hpp
# run_code_on_dllmain.cpp
# stdafx.cpp
# stdafx.h
# targetver.h
# pydevd_concurrency_logger.py
# pydevd_thread_wrappers.py
# __init__.py
# django_debug.py
# jinja2_debug.py
# __init__.py
# README.md
# __init__.py
# pydevd_helpers.py
# pydevd_plugins_django_form_str.py
# pydevd_plugin_numpy_types.py
# __init__.py
# inputhook.py
# inputhookglut.py
# inputhookgtk.py
# inputhookgtk3.py
# inputhookpyglet.py
# inputhookqt4.py
# inputhookqt5.py
# inputhooktk.py
# inputhookwx.py
# matplotlibtools.py
# qt.py
# qt_for_kernel.py
# qt_loaders.py
# README
# version.py
# __init__.py
# sitecustomize.py
# __not_in_default_pythonpath.txt
# pydevconsole_code_for_ironpython.py
# pydevd_additional_thread_info.py
# pydevd_additional_thread_info_regular.py
# pydevd_api.py
# pydevd_breakpoints.py
# pydevd_bytecode_utils.py
# pydevd_code_to_source.py
# pydevd_collect_bytecode_info.py
# pydevd_comm.py
# pydevd_command_line_handling.py
# pydevd_comm_constants.py
# pydevd_console.py
# pydevd_constants.py
# pydevd_custom_frames.py
# pydevd_cython.c
# pydevd_cython.cp39-win32.pyd
# pydevd_cython.cp39-win_amd64.pyd
# pydevd_cython.cpython-39-darwin.so
# pydevd_cython.cpython-39-x86_64-linux-gnu.so
# pydevd_cython.pxd
# pydevd_cython.pyx
# pydevd_cython_wrapper.py
# pydevd_daemon_thread.py
# pydevd_defaults.py
# pydevd_dont_trace.py
# pydevd_dont_trace_files.py
# pydevd_exec.py
# pydevd_exec2.py
# pydevd_extension_api.py
# pydevd_extension_utils.py
# pydevd_filtering.py
# pydevd_frame.py
# pydevd_frame_utils.py
# pydevd_import_class.py
# pydevd_io.py
# pydevd_json_debug_options.py
# pydevd_net_command.py
# pydevd_net_command_factory_json.py
# pydevd_net_command_factory_xml.py
# pydevd_plugin_utils.py
# pydevd_process_net_command.py
# pydevd_process_net_command_json.py
# pydevd_referrers.py
# pydevd_reload.py
# pydevd_resolver.py
# pydevd_safe_repr.py
# pydevd_save_locals.py
# pydevd_signature.py
# pydevd_source_mapping.py
# pydevd_stackless.py
# pydevd_suspended_frames.py
# pydevd_thread_lifecycle.py
# pydevd_timeout.py
# pydevd_traceproperty.py
# pydevd_trace_api.py
# pydevd_trace_dispatch.py
# pydevd_trace_dispatch_regular.py
# pydevd_utils.py
# pydevd_vars.py
# pydevd_vm_type.py
# pydevd_xml.py
# __init__.py
# debugProtocol.json
# debugProtocolCustom.json
# pydevd_base_schema.py
# pydevd_schema.py
# pydevd_schema_log.py
# __init__.py
# __main__pydevd_gen_debug_adapter_protocol.py
# .gitignore
# pydevd_frame_evaluator.c
# pydevd_frame_evaluator.cp39-win32.pyd
# pydevd_frame_evaluator.cp39-win_amd64.pyd
# pydevd_frame_evaluator.cpython-39-darwin.so
# pydevd_frame_evaluator.cpython-39-x86_64-linux-gnu.so
# pydevd_frame_evaluator.pxd
# pydevd_frame_evaluator.pyx
# pydevd_frame_evaluator.template.pyx
# pydevd_frame_eval_cython_wrapper.py
# pydevd_frame_eval_main.py
# pydevd_frame_tracing.py
# pydevd_modify_bytecode.py
# release_mem.h
# __init__.py
# pydevd_fix_code.py
# README.txt
# __init__.py
# bytecode.py
# cfg.py
# concrete.py
# flags.py
# instr.py
# peephole_opt.py
# __init__.py
# test_bytecode.py
# test_cfg.py
# test_code.py
# test_concrete.py
# test_flags.py
# test_instr.py
# test_misc.py
# test_peephole_opt.py
# util_annotation.py
# __init__.py
# pydev_console_utils.py
# pydev_imports.py
# pydev_import_hook.py
# pydev_ipython_console.py
# pydev_ipython_console_011.py
# pydev_is_thread_alive.py
# pydev_localhost.py
# pydev_log.py
# pydev_monkey.py
# pydev_monkey_qt.py
# pydev_override.py
# pydev_umd.py
# pydev_versioncheck.py
# _pydev_calltip_util.py
# _pydev_completer.py
# _pydev_filesystem_encoding.py
# _pydev_getopt.py
# _pydev_imports_tipper.py
# _pydev_jy_imports_tipper.py
# _pydev_log.py
# _pydev_tipper_common.py
# __init__.py
# scandir_vendored.py
# __init__.py
# _pydev_BaseHTTPServer.py
# _pydev_execfile.py
# _pydev_inspect.py
# _pydev_pkgutil_old.py
# _pydev_saved_modules.py
# _pydev_SimpleXMLRPCServer.py
# _pydev_SocketServer.py
# _pydev_sys_patch.py
# _pydev_xmlrpclib.py
# __init__.py
# pydev_runfiles.py
# pydev_runfiles_coverage.py
# pydev_runfiles_nose.py
# pydev_runfiles_parallel.py
# pydev_runfiles_parallel_client.py
# pydev_runfiles_pytest2.py
# pydev_runfiles_unittest.py
# pydev_runfiles_xml_rpc.py
# __init__.py
# api.py
# comments.py
# core.py
# exceptions.py
# files.py
# format.py
# hooks.py
# identify.py
# io.py
# literal.py
# logo.py
# main.py
# output.py
# parse.py
# place.py
# profiles.py
# py.typed
# pylama_isort.py
# sections.py
# settings.py
# setuptools_commands.py
# sorting.py
# utils.py
# wrap.py
# wrap_modes.py
# _version.py
# __init__.py
# __main__.py
# finders.py
# __init__.py
# all.py
# py2.py
# py27.py
# py3.py
# py310.py
# py35.py
# py36.py
# py37.py
# py38.py
# py39.py
# __init__.py
# _dataclasses.py
# __init__.py
# LICENSE
# py.typed
# _parser.py
# _re.py
# __init__.py
# run_adapter.py
# unittest_discovery.py
# __init__.py
# discovery.py
# errors.py
# info.py
# report.py
# util.py
# __init__.py
# __main__.py
# _cli.py
# _discovery.py
# _pytest_item.py
# __init__.py
# logParser.py
# demo.gif
# logo.svg
# report_issue_template.md
# report_issue_user_settings.json
# debug.svg
# discovering-tests.svg
# export_to_python.svg
# open-file.svg
# play.svg
# refresh.svg
# repl.svg
# restart-kernel.svg
# run-failed-tests.svg
# run-file.svg
# run-tests.svg
# start.svg
# status-error.svg
# status-ok.svg
# status-unknown.svg
# stop.svg
# trusted.svg
# un-trusted.svg
# debug.svg
# discovering-tests.svg
# export_to_python.svg
# open-file.svg
# play.svg
# refresh.svg
# repl.svg
# restart-kernel.svg
# run-failed-tests.svg
# run-file.svg
# run-tests.svg
# start.svg
# status-error.svg
# status-ok.svg
# status-unknown.svg
# stop.svg
# trusted.svg
# un-trusted.svg
# create-notebook.svg
# data-science.svg
# install-python-linux.md
# install-python-macos.md
# install-python-windows.md
# interactive-window.svg
# learnmore.svg
# open-folder.svg
# play-button-dark.png
# python-interpreter-v2.svg
# python-interpreter.svg
# rundebug2.svg
# conda-environment.json
# conda-meta.json
# condarc.json
# .vsixmanifest
# CHANGELOG.md
# icon.png
# LICENSE.txt
# package.json
# README.md
# .vsixmanifest
# CHANGELOG.md
# icon.png
# LICENSE.md
# package.json
# README.md
# extension.js
# .vsixmanifest
# BACKERS.md
# CHANGELOG.md
# LICENSE.txt
# package.json
# README.md
# tslint.json
# bug_report.md
# config.yml
# feature_request.md
# main.yml
# alipay.png
# CodeStream.png
# logo.png
# stepsize.png
# tabnine.png
# usage.gif
# usageRunByLanguage.gif
# zhihu.png
# .npmignore
# applicationinsights.js
# License.txt
# package.json
# README.md
# tsconfig.json
# typings.json
# ClientRequestParser.js
# ClientRequests.js
# Console.js
# CorrelationContextManager.js
# Exceptions.js
# Performance.js
# RequestParser.js
# ServerRequestParser.js
# ServerRequests.js
# Channel.js
# Client.js
# Config.js
# Context.js
# Contracts.js
# Logging.js
# RequestResponseHeaders.js
# Sender.js
# Util.js
# generateSchema.ps1
# AvailabilityData.bond
# Base.bond
# ContextTagKeys.bond
# Data.bond
# DataPoint.bond
# DataPointType.bond
# Domain.bond
# Envelope.bond
# EventData.bond
# ExceptionData.bond
# ExceptionDetails.bond
# MessageData.bond
# MetricData.bond
# PageViewData.bond
# RemoteDependencyData.bond
# RequestData.bond
# SeverityLevel.bond
# StackFrame.bond
# typings.json
# typings.json
# typings.json
# CHANGELOG.md
# index.js
# LICENSE
# package.json
# README.md
# compile.js
# constants.js
# expand.js
# parse.js
# stringify.js
# utils.js
# index.js
# LICENSE
# package.json
# README.md
# index.js
# LICENSE
# package.json
# README.md
# CHANGELOG.md
# index.js
# LICENSE
# package.json
# README.md
# CHANGELOG.md
# index.js
# LICENSE
# package.json
# README.md
# constants.js
# parse.js
# picomatch.js
# scan.js
# utils.js
# index.js
# LICENSE
# package.json
# README.md
# cli.js
# index.d.ts
# index.js
# LICENSE
# package.json
# README.md
# CHANGELOG.md
# LICENSE
# LICENSE.wrapped
# package.json
# README.md
# async-test.js
# fake-async-test.js
# jasmine-patch.js
# jasmine-patch.min.js
# long-stack-trace-zone.js
# long-stack-trace-zone.min.js
# mocha-patch.js
# mocha-patch.min.js
# proxy.js
# proxy.min.js
# sync-test.js
# task-tracking.js
# task-tracking.min.js
# web-api.js
# webapis-media-query.js
# webapis-notification.js
# wtf.js
# wtf.min.js
# zone-node.js
# zone.js
# zone.js.d.ts
# zone.min.js
# zone.ts
# browser.ts
# define-property.ts
# event-target.ts
# property-descriptor.ts
# register-element.ts
# rollup-main.ts
# webapis-media-query.ts
# webapis-notification.ts
# websocket.ts
# timers.ts
# utils.ts
# jasmine.ts
# mocha.ts
# events.ts
# fs.ts
# node.ts
# async-test.ts
# fake-async-test.ts
# long-stack-trace.ts
# proxy.ts
# sync-test.ts
# task-tracking.ts
# wtf.ts
# appInsightsClient.js
# codeManager.js
# constants.js
# extension.js
# utility.js
# code-runner-output.tmLanguage
# .vsixmanifest
# icon.png
# package.json
# README.md
# screenshot.PNG
# launch.json
# 8-Colour-Dark.tmTheme
# .vsixmanifest
# azure-pipelines.yml
# CHANGELOG.md
# demo.py
# DEVELOP.md
# LICENSE.txt
# package.json
# README.md
# smoke_test.py
# tsconfig.json
# FUNDING.yml
# PULL_REQUEST_TEMPLATE.md
# bad_indentation.md
# bug_report.md
# feature_request.md
# CHANGELOG.md
# LICENSE
# package.json
# README.md
# index.js
# extension.js
# indent.js
# parser.js
# auto-demo.scpt
# demo.gif
# logo.png
# .eslintignore
# .vsixmanifest
# cgmanifest.json
# CHANGELOG.md
# icon.png
# LICENSE.txt
# package.json
# package.nls.cs.json
# package.nls.de.json
# package.nls.es.json
# package.nls.fr.json
# package.nls.it.json
# package.nls.ja.json
# package.nls.json
# package.nls.ko.json
# package.nls.pl.json
# package.nls.pt-BR.json
# package.nls.qps-ploc.json
# package.nls.ru.json
# package.nls.tr.json
# package.nls.zh-Hans.json
# package.nls.zh-Hant.json
# README.md
# requirements.txt
# SECURITY.md
# SUPPORT.md
# telemetry.json
# ThirdPartyNotices-Repository.txt
# ThirdPartyNotices.txt
# extension.browser.js
# extension.browser.js.LICENSE.txt
# addIcon.PNG
# codeIcon.PNG
# dataViewerIcon.PNG
# exportIcon.PNG
# markdownIcon.PNG
# playIcon.PNG
# plotViewerIcon.PNG
# variableExplorerIcon.PNG
# pip-requirements.json
# 394.js
# 505.js
# 698.js
# 698.js.LICENSE.txt
# extension.js
# extension.js.LICENSE.txt
# extension.js.map.disabled
# nls.bundle.cs.json
# nls.bundle.de.json
# nls.bundle.es.json
# nls.bundle.fr.json
# nls.bundle.it.json
# nls.bundle.ja.json
# nls.bundle.ko.json
# nls.bundle.pl.json
# nls.bundle.pt-BR.json
# nls.bundle.qps-ploc.json
# nls.bundle.ru.json
# nls.bundle.tr.json
# nls.bundle.zh-Hans.json
# nls.bundle.zh-Hant.json
# nls.metadata.header.json
# nls.metadata.json
# package.json
# diff-match-patch.js
# node-stream-zip.js
# node-stream-zip.js.LICENSE.txt
# request-progress.js
# request.js
# request.js.LICENSE.txt
# source-map-support.js
# sudo-prompt.js
# xml2js.js
# xml2js.js.LICENSE.txt
# Ll.js
# Lm.js
# Lo.js
# Lt.js
# Lu.js
# Mc.js
# Mn.js
# Nd.js
# Nl.js
# Pc.js
# macPythonInterpreter.nls.metadata.json
# powerShellActivation.nls.metadata.json
# pythonInterpreter.nls.metadata.json
# service.nls.metadata.json
# moduleInstaller.nls.metadata.json
# productInstaller.nls.metadata.json
# fileDownloader.nls.metadata.json
# localize.nls.metadata.json
# banner.nls.metadata.json
# factory.nls.metadata.json
# provider.nls.metadata.json
# pyramidLaunch.nls.metadata.json
# childProcessAttachService.nls.metadata.json
# blackFormatter.nls.metadata.json
# pythonPathUpdaterService.nls.metadata.json
# setInterpreter.nls.metadata.json
# index.nls.metadata.json
# watcher.nls.metadata.json
# linterCommands.nls.metadata.json
# standard.nls.metadata.json
# importSortProvider.nls.metadata.json
# tensorBoardSession.nls.metadata.json
# tensorBoardSessionProvider.nls.metadata.json
# helper.nls.metadata.json
# debugLauncher.nls.metadata.json
# .env
# get-pip.py
# get_output_via_markers.py
# install_debugpy.py
# interpreterInfo.py
# linter.py
# normalizeSelection.py
# Notebooks intro.ipynb
# printEnvVariables.py
# printEnvVariablesToFile.py
# pyproject.toml
# run-jedi-language-server.py
# shell_exec.py
# sortImports.py
# tensorboard_launcher.py
# testlauncher.py
# visualstudio_py_testlauncher.py
# settings.json
# README.md
# typing_extensions.py
# zipp.py
# jedi-language-server
# py.typed
# rst.py
# __init__.py
# py.typed
# _collections.py
# _compat.py
# _functools.py
# _itertools.py
# __init__.py
# cache.py
# common.py
# debug.py
# file_io.py
# parser_utils.py
# settings.py
# utils.py
# _compatibility.py
# __init__.py
# __main__.py
# classes.py
# completion.py
# completion_cache.py
# environment.py
# errors.py
# exceptions.py
# file_name.py
# helpers.py
# interpreter.py
# keywords.py
# project.py
# replstartup.py
# strings.py
# __init__.py
# extract.py
# __init__.py
# analysis.py
# arguments.py
# base_value.py
# cache.py
# context.py
# docstrings.py
# docstring_utils.py
# dynamic_params.py
# filters.py
# finder.py
# flow_analysis.py
# helpers.py
# imports.py
# lazy_value.py
# names.py
# param.py
# parser_cache.py
# recursion.py
# references.py
# signature.py
# star_args.py
# syntax_tree.py
# sys_path.py
# utils.py
# __init__.py
# access.py
# getattr_static.py
# mixed.py
# value.py
# __init__.py
# functions.py
# __init__.py
# __main__.py
# annotation.py
# base.py
# conversion.py
# generics.py
# stub_value.py
# typeshed.py
# type_var.py
# typing.py
# utils.py
# __init__.py
# decorator.py
# dynamic_arrays.py
# function.py
# instance.py
# iterable.py
# klass.py
# module.py
# namespace.py
# __init__.py
# django.py
# flask.py
# pytest.py
# registry.py
# stdlib.py
# __init__.py
# LICENSE.txt
# shortcuts.pyi
# __init__.pyi
# config.pyi
# registry.pyi
# __init__.pyi
# global_settings.pyi
# __init__.pyi
# __init__.pyi
# i18n.pyi
# static.pyi
# __init__.pyi
# __init__.pyi
# actions.pyi
# apps.pyi
# checks.pyi
# decorators.pyi
# filters.pyi
# forms.pyi
# helpers.pyi
# models.pyi
# options.pyi
# sites.pyi
# tests.pyi
# utils.pyi
# widgets.pyi
# __init__.pyi
# admin_list.pyi
# admin_modify.pyi
# admin_static.pyi
# admin_urls.pyi
# base.pyi
# log.pyi
# __init__.pyi
# autocomplete.pyi
# decorators.pyi
# main.pyi
# __init__.pyi
# middleware.pyi
# urls.pyi
# utils.pyi
# views.pyi
# __init__.pyi
# admin.pyi
# apps.pyi
# backends.pyi
# base_user.pyi
# checks.pyi
# context_processors.pyi
# decorators.pyi
# forms.pyi
# hashers.pyi
# middleware.pyi
# mixins.pyi
# models.pyi
# password_validation.pyi
# signals.pyi
# tokens.pyi
# urls.pyi
# validators.pyi
# views.pyi
# __init__.pyi
# modwsgi.pyi
# __init__.pyi
# __init__.pyi
# changepassword.pyi
# createsuperuser.pyi
# __init__.pyi
# admin.pyi
# apps.pyi
# checks.pyi
# fields.pyi
# forms.pyi
# models.pyi
# views.pyi
# __init__.pyi
# __init__.pyi
# remove_stale_contenttypes.pyi
# __init__.pyi
# forms.pyi
# middleware.pyi
# models.pyi
# sitemaps.pyi
# urls.pyi
# views.pyi
# __init__.pyi
# flatpages.pyi
# __init__.pyi
# __init__.pyi
# __init__.pyi
# fields.pyi
# __init__.pyi
# __init__.pyi
# humanize.pyi
# __init__.pyi
# api.pyi
# constants.pyi
# context_processors.pyi
# middleware.pyi
# utils.pyi
# views.pyi
# __init__.pyi
# base.pyi
# cookie.pyi
# fallback.pyi
# ...
# nmakehlp.c
# rules.vc
# targets.vc
# tcl.nmake
# pkgIndex.tcl
# tclreg13.dll
# platform-1.0.14.tm
# shell-1.1.4.tm
# msgcat-1.6.1.tm
# tcltest-2.5.0.tm
# http-2.9.0.tm
# auto.tcl
# clock.tcl
# history.tcl
# init.tcl
# package.tcl
# parray.tcl
# safe.tcl
# tclIndex
# tm.tcl
# word.tcl
# ascii.enc
# big5.enc
# cp1250.enc
# cp1251.enc
# cp1252.enc
# cp1253.enc
# cp1254.enc
# cp1255.enc
# cp1256.enc
# cp1257.enc
# cp1258.enc
# cp437.enc
# cp737.enc
# cp775.enc
# cp850.enc
# cp852.enc
# cp855.enc
# cp857.enc
# cp860.enc
# cp861.enc
# cp862.enc
# cp863.enc
# cp864.enc
# cp865.enc
# cp866.enc
# cp869.enc
# cp874.enc
# cp932.enc
# cp936.enc
# cp949.enc
# cp950.enc
# dingbats.enc
# ebcdic.enc
# euc-cn.enc
# euc-jp.enc
# euc-kr.enc
# gb12345.enc
# gb1988.enc
# gb2312-raw.enc
# gb2312.enc
# iso2022-jp.enc
# iso2022-kr.enc
# iso2022.enc
# iso8859-1.enc
# iso8859-10.enc
# iso8859-13.enc
# iso8859-14.enc
# iso8859-15.enc
# iso8859-16.enc
# iso8859-2.enc
# iso8859-3.enc
# iso8859-4.enc
# iso8859-5.enc
# iso8859-6.enc
# iso8859-7.enc
# iso8859-8.enc
# iso8859-9.enc
# jis0201.enc
# jis0208.enc
# jis0212.enc
# koi8-r.enc
# koi8-u.enc
# ksc5601.enc
# macCentEuro.enc
# macCroatian.enc
# macCyrillic.enc
# macDingbats.enc
# macGreek.enc
# macIceland.enc
# macJapan.enc
# macRoman.enc
# macRomania.enc
# macThai.enc
# macTurkish.enc
# macUkraine.enc
# shiftjis.enc
# symbol.enc
# tis-620.enc
# http.tcl
# pkgIndex.tcl
# af.msg
# af_za.msg
# ar.msg
# ar_in.msg
# ar_jo.msg
# ar_lb.msg
# ar_sy.msg
# be.msg
# bg.msg
# bn.msg
# bn_in.msg
# ca.msg
# cs.msg
# da.msg
# de.msg
# de_at.msg
# de_be.msg
# el.msg
# en_au.msg
# en_be.msg
# en_bw.msg
# en_ca.msg
# en_gb.msg
# en_hk.msg
# en_ie.msg
# en_in.msg
# en_nz.msg
# en_ph.msg
# en_sg.msg
# en_za.msg
# en_zw.msg
# eo.msg
# es.msg
# es_ar.msg
# es_bo.msg
# es_cl.msg
# es_co.msg
# es_cr.msg
# es_do.msg
# es_ec.msg
# es_gt.msg
# es_hn.msg
# es_mx.msg
# es_ni.msg
# es_pa.msg
# es_pe.msg
# es_pr.msg
# es_py.msg
# es_sv.msg
# es_uy.msg
# es_ve.msg
# et.msg
# eu.msg
# eu_es.msg
# fa.msg
# fa_in.msg
# fa_ir.msg
# fi.msg
# fo.msg
# fo_fo.msg
# fr.msg
# fr_be.msg
# fr_ca.msg
# fr_ch.msg
# ga.msg
# ga_ie.msg
# gl.msg
# gl_es.msg
# gv.msg
# gv_gb.msg
# he.msg
# hi.msg
# hi_in.msg
# hr.msg
# hu.msg
# id.msg
# id_id.msg
# is.msg
# it.msg
# it_ch.msg
# ja.msg
# kl.msg
# kl_gl.msg
# ko.msg
# kok.msg
# kok_in.msg
# ko_kr.msg
# kw.msg
# kw_gb.msg
# lt.msg
# lv.msg
# mk.msg
# mr.msg
# mr_in.msg
# ms.msg
# ms_my.msg
# mt.msg
# nb.msg
# nl.msg
# nl_be.msg
# nn.msg
# pl.msg
# pt.msg
# pt_br.msg
# ro.msg
# ru.msg
# ru_ua.msg
# sh.msg
# sk.msg
# sl.msg
# sq.msg
# sr.msg
# sv.msg
# sw.msg
# ta.msg
# ta_in.msg
# te.msg
# te_in.msg
# th.msg
# tr.msg
# uk.msg
# vi.msg
# zh.msg
# zh_cn.msg
# zh_hk.msg
# zh_sg.msg
# zh_tw.msg
# optparse.tcl
# pkgIndex.tcl
# CET
# CST6CDT
# Cuba
# EET
# Egypt
# Eire
# EST
# EST5EDT
# GB
# GB-Eire
# GMT
# GMT+0
# GMT-0
# GMT0
# Greenwich
# Hongkong
# HST
# Iceland
# Iran
# Israel
# Jamaica
# Japan
# Kwajalein
# Libya
# MET
# MST
# MST7MDT
# Navajo
# NZ
# NZ-CHAT
# Poland
# Portugal
# PRC
# PST8PDT
# ROC
# ROK
# Singapore
# Turkey
# UCT
# Universal
# UTC
# W-SU
# WET
# Zulu
# Abidjan
# Accra
# Addis_Ababa
# Algiers
# Asmara
# Asmera
# Bamako
# Bangui
# Banjul
# Bissau
# Blantyre
# Brazzaville
# Bujumbura
# Cairo
# Casablanca
# Ceuta
# Conakry
# Dakar
# Dar_es_Salaam
# Djibouti
# Douala
# El_Aaiun
# Freetown
# Gaborone
# Harare
# Johannesburg
# Juba
# Kampala
# Khartoum
# Kigali
# Kinshasa
# Lagos
# Libreville
# Lome
# Luanda
# Lubumbashi
# Lusaka
# Malabo
# Maputo
# Maseru
# Mbabane
# Mogadishu
# Monrovia
# Nairobi
# Ndjamena
# Niamey
# Nouakchott
# Ouagadougou
# Porto-Novo
# Sao_Tome
# Timbuktu
# Tripoli
# Tunis
# Windhoek
# Adak
# Anchorage
# Anguilla
# Antigua
# Araguaina
# Aruba
# Asuncion
# Atikokan
# Atka
# Bahia
# Bahia_Banderas
# Barbados
# Belem
# Belize
# Blanc-Sablon
# Boa_Vista
# Bogota
# Boise
# Buenos_Aires
# Cambridge_Bay
# Campo_Grande
# Cancun
# Caracas
# Catamarca
# Cayenne
# Cayman
# Chicago
# Chihuahua
# Coral_Harbour
# Cordoba
# Costa_Rica
# Creston
# Cuiaba
# Curacao
# Danmarkshavn
# Dawson
# Dawson_Creek
# Denver
# Detroit
# Dominica
# Edmonton
# Eirunepe
# El_Salvador
# Ensenada
# Fortaleza
# Fort_Nelson
# Fort_Wayne
# Glace_Bay
# Godthab
# Goose_Bay
# Grand_Turk
# Grenada
# Guadeloupe
# Guatemala
# Guayaquil
# Guyana
# Halifax
# Havana
# Hermosillo
# Indianapolis
# Inuvik
# Iqaluit
# Jamaica
# Jujuy
# Juneau
# Knox_IN
# Kralendijk
# La_Paz
# Lima
# Los_Angeles
# Louisville
# Lower_Princes
# Maceio
# Managua
# Manaus
# Marigot
# Martinique
# Matamoros
# Mazatlan
# Mendoza
# Menominee
# Merida
# Metlakatla
# Mexico_City
# Miquelon
# Moncton
# Monterrey
# Montevideo
# Montreal
# Montserrat
# Nassau
# New_York
# Nipigon
# Nome
# Noronha
# Ojinaga
# Panama
# Pangnirtung
# Paramaribo
# Phoenix
# Port-au-Prince
# Porto_Acre
# Porto_Velho
# Port_of_Spain
# Puerto_Rico
# Punta_Arenas
# Rainy_River
# Rankin_Inlet
# Recife
# Regina
# Resolute
# Rio_Branco
# Rosario
# Santarem
# Santa_Isabel
# Santiago
# Santo_Domingo
# Sao_Paulo
# Scoresbysund
# Shiprock
# Sitka
# St_Barthelemy
# St_Johns
# St_Kitts
# St_Lucia
# St_Thomas
# St_Vincent
# Swift_Current
# Tegucigalpa
# Thule
# Thunder_Bay
# Tijuana
# Toronto
# Tortola
# Vancouver
# Virgin
# Whitehorse
# Winnipeg
# Yakutat
# Yellowknife
# Buenos_Aires
# Catamarca
# ComodRivadavia
# Cordoba
# Jujuy
# La_Rioja
# Mendoza
# Rio_Gallegos
# Salta
# San_Juan
# San_Luis
# Tucuman
# Ushuaia
# Indianapolis
# Knox
# Marengo
# Petersburg
# Tell_City
# Vevay
# Vincennes
# Winamac
# Louisville
# Monticello
# Beulah
# Center
# New_Salem
# Casey
# Davis
# DumontDUrville
# Macquarie
# Mawson
# McMurdo
# Palmer
# Rothera
# South_Pole
# Syowa
# Troll
# Vostok
# Longyearbyen
# Aden
# Almaty
# Amman
# Anadyr
# Aqtau
# Aqtobe
# Ashgabat
# Ashkhabad
# Atyrau
# Baghdad
# Bahrain
# Baku
# Bangkok
# Barnaul
# Beirut
# Bishkek
# Brunei
# Calcutta
# Chita
# Choibalsan
# Chongqing
# Chungking
# Colombo
# Dacca
# Damascus
# Dhaka
# Dili
# Dubai
# Dushanbe
# Famagusta
# Gaza
# Harbin
# Hebron
# Hong_Kong
# Hovd
# Ho_Chi_Minh
# Irkutsk
# Istanbul
# Jakarta
# Jayapura
# Jerusalem
# Kabul
# Kamchatka
# Karachi
# Kashgar
# Kathmandu
# Katmandu
# Khandyga
# Kolkata
# Krasnoyarsk
# Kuala_Lumpur
# Kuching
# Kuwait
# Macao
# Macau
# Magadan
# Makassar
# Manila
# Muscat
# Nicosia
# Novokuznetsk
# Novosibirsk
# Omsk
# Oral
# Phnom_Penh
# Pontianak
# Pyongyang
# Qatar
# Qyzylorda
# Rangoon
# Riyadh
# Saigon
# Sakhalin
# Samarkand
# Seoul
# Shanghai
# Singapore
# Srednekolymsk
# Taipei
# Tashkent
# Tbilisi
# Tehran
# Tel_Aviv
# Thimbu
# Thimphu
# Tokyo
# Tomsk
# Ujung_Pandang
# Ulaanbaatar
# Ulan_Bator
# Urumqi
# Ust-Nera
# Vientiane
# Vladivostok
# Yakutsk
# Yangon
# Yekaterinburg
# Yerevan
# Azores
# Bermuda
# Canary
# Cape_Verde
# Faeroe
# Faroe
# Jan_Mayen
# Madeira
# Reykjavik
# South_Georgia
# Stanley
# St_Helena
# ACT
# Adelaide
# Brisbane
# Broken_Hill
# Canberra
# Currie
# Darwin
# Eucla
# Hobart
# LHI
# Lindeman
# Lord_Howe
# Melbourne
# North
# NSW
# Perth
# Queensland
# South
# Sydney
# Tasmania
# Victoria
# West
# Yancowinna
# Acre
# DeNoronha
# East
# West
# Atlantic
# Central
# East-Saskatchewan
# Eastern
# Mountain
# Newfoundland
# Pacific
# Saskatchewan
# Yukon
# Continental
# EasterIsland
# GMT
# GMT+0
# GMT+1
# GMT+10
# GMT+11
# GMT+12
# GMT+2
# GMT+3
# GMT+4
# GMT+5
# GMT+6
# GMT+7
# GMT+8
# GMT+9
# GMT-0
# GMT-1
# GMT-10
# GMT-11
# GMT-12
# GMT-13
# GMT-14
# GMT-2
# GMT-3
# GMT-4
# GMT-5
# GMT-6
# GMT-7
# GMT-8
# GMT-9
# GMT0
# Greenwich
# UCT
# Universal
# UTC
# Zulu
# Amsterdam
# Andorra
# Astrakhan
# Athens
# Belfast
# Belgrade
# Berlin
# Bratislava
# Brussels
# Bucharest
# Budapest
# Busingen
# Chisinau
# Copenhagen
# Dublin
# Gibraltar
# Guernsey
# Helsinki
# Isle_of_Man
# Istanbul
# Jersey
# Kaliningrad
# Kiev
# Kirov
# Lisbon
# Ljubljana
# London
# Luxembourg
# Madrid
# Malta
# Mariehamn
# Minsk
# Monaco
# Moscow
# Nicosia
# Oslo
# Paris
# Podgorica
# Prague
# Riga
# Rome
# Samara
# San_Marino
# Sarajevo
# Saratov
# Simferopol
# Skopje
# Sofia
# Stockholm
# Tallinn
# Tirane
# Tiraspol
# Ulyanovsk
# Uzhgorod
# Vaduz
# Vatican
# Vienna
# Vilnius
# Volgograd
# Warsaw
# Zagreb
# Zaporozhye
# Zurich
# Antananarivo
# Chagos
# Christmas
# Cocos
# Comoro
# Kerguelen
# Mahe
# Maldives
# Mauritius
# Mayotte
# Reunion
# BajaNorte
# BajaSur
# General
# Apia
# Auckland
# Bougainville
# Chatham
# Chuuk
# Easter
# Efate
# Enderbury
# Fakaofo
# Fiji
# Funafuti
# Galapagos
# Gambier
# Guadalcanal
# Guam
# Honolulu
# Johnston
# Kiritimati
# Kosrae
# Kwajalein
# Majuro
# Marquesas
# Midway
# Nauru
# Niue
# Norfolk
# Noumea
# Pago_Pago
# Palau
# Pitcairn
# Pohnpei
# Ponape
# Port_Moresby
# Rarotonga
# Saipan
# Samoa
# Tahiti
# Tarawa
# Tongatapu
# Truk
# Wake
# Wallis
# Yap
# AST4
# AST4ADT
# CST6
# CST6CDT
# EST5
# EST5EDT
# HST10
# MST7
# MST7MDT
# PST8
# PST8PDT
# YST9
# YST9YDT
# Alaska
# Aleutian
# Arizona
# Central
# East-Indiana
# Eastern
# Hawaii
# Indiana-Starke
# Michigan
# Mountain
# Pacific
# Pacific-New
# Samoa
# Balloon.tcl
# BtnBox.tcl
# ChkList.tcl
# CObjView.tcl
# ComboBox.tcl
# Compat.tcl
# Console.tcl
# Control.tcl
# DefSchm.tcl
# DialogS.tcl
# DirBox.tcl
# DirDlg.tcl
# DirList.tcl
# DirTree.tcl
# DragDrop.tcl
# DtlList.tcl
# EFileBox.tcl
# EFileDlg.tcl
# Event.tcl
# FileBox.tcl
# FileCbx.tcl
# FileDlg.tcl
# FileEnt.tcl
# FloatEnt.tcl
# fs.tcl
# Grid.tcl
# HList.tcl
# HListDD.tcl
# IconView.tcl
# Init.tcl
# LabEntry.tcl
# LabFrame.tcl
# LabWidg.tcl
# ListNBk.tcl
# Makefile
# Meter.tcl
# MultView.tcl
# NoteBook.tcl
# OldUtil.tcl
# OptMenu.tcl
# PanedWin.tcl
# pkgIndex.tcl
# PopMenu.tcl
# Primitiv.tcl
# ResizeH.tcl
# Select.tcl
# SGrid.tcl
# Shell.tcl
# SHList.tcl
# SimpDlg.tcl
# SListBox.tcl
# StackWin.tcl
# StatBar.tcl
# StdBBox.tcl
# StdShell.tcl
# SText.tcl
# STList.tcl
# SWidget.tcl
# SWindow.tcl
# Tix.tcl
# tix84.dll
# tix84.lib
# TList.tcl
# Tree.tcl
# Utils.tcl
# Variable.tcl
# VResize.tcl
# VStack.tcl
# VTree.tcl
# WInfo.tcl
# act_fold.gif
# act_fold.xbm
# act_fold.xpm
# balarrow.xbm
# cbxarrow.xbm
# ck_def.xbm
# ck_off.xbm
# ck_on.xbm
# cross.xbm
# decr.xbm
# drop.xbm
# file.gif
# file.xbm
# file.xpm
# folder.gif
# folder.xbm
# folder.xpm
# harddisk.xbm
# hourglas.mask
# hourglas.xbm
# incr.xbm
# info.gif
# info.xpm
# maximize.xbm
# minimize.xbm
# minus.gif
# minus.xbm
# minus.xpm
# minusarm.gif
# minusarm.xbm
# minusarm.xpm
# mktransgif.tcl
# network.xbm
# no_entry.gif
# no_entry.xpm
# openfile.xbm
# openfold.gif
# openfold.xbm
# openfold.xpm
# plus.gif
# plus.xbm
# plus.xpm
# plusarm.gif
# plusarm.xbm
# plusarm.xpm
# resize1.xbm
# resize2.xbm
# restore.xbm
# srcfile.gif
# srcfile.xbm
# srcfile.xpm
# system.xbm
# textfile.gif
# textfile.xbm
# textfile.xpm
# tick.xbm
# warning.gif
# warning.xpm
# MkChoose.tcl
# MkDirLis.tcl
# MkSample.tcl
# MkScroll.tcl
# tclIndex
# tixwidgets.tcl
# widget
# about.xpm
# bold.xbm
# capital.xbm
# centerj.xbm
# code.xpm
# combobox.xbm
# combobox.xpm
# drivea.xbm
# drivea.xpm
# exit.xpm
# filebox.xbm
# filebox.xpm
# harddisk.xbm
# harddisk.xpm
# italic.xbm
# justify.xbm
# leftj.xbm
# netw.xbm
# netw.xpm
# network.xbm
# network.xpm
# optmenu.xpm
# rightj.xbm
# select.xpm
# tix.gif
# underlin.xbm
# AllSampl.tcl
# ArrowBtn.tcl
# Balloon.tcl
# BtnBox.tcl
# ChkList.tcl
# CmpImg.tcl
# CmpImg1.tcl
# CmpImg2.tcl
# CmpImg3.tcl
# CmpImg4.tcl
# CObjView.tcl
# ComboBox.tcl
# Control.tcl
# DirDlg.tcl
# DirList.tcl
# DirTree.tcl
# DragDrop.tcl
# DynTree.tcl
# EditGrid.tcl
# EFileDlg.tcl
# FileDlg.tcl
# FileEnt.tcl
# HList1.tcl
# LabEntry.tcl
# LabFrame.tcl
# ListNBK.tcl
# Meter.tcl
# NoteBook.tcl
# OptMenu.tcl
# PanedWin.tcl
# PopMenu.tcl
# Sample.tcl
# Select.tcl
# SGrid0.tcl
# SGrid1.tcl
# SHList.tcl
# SHList2.tcl
# SListBox.tcl
# StdBBox.tcl
# SText.tcl
# STList1.tcl
# STList2.tcl
# STList3.tcl
# SWindow.tcl
# Tree.tcl
# Xpm.tcl
# Xpm1.tcl
# 10Point.fs
# 10Point.fsc
# 12Point.fs
# 12Point.fsc
# 14Point.fs
# 14Point.fsc
# Bisque.cs
# Bisque.csc
# Blue.cs
# Blue.csc
# Gray.cs
# Gray.csc
# Makefile
# Old12Pt.fs
# Old14Pt.fs
# pkgIndex.tcl
# SGIGray.cs
# SGIGray.csc
# TixGray.cs
# TixGray.csc
# tixmkpref
# TK.cs
# TK.csc
# TK.fs
# TK.fsc
# TkWin.cs
# TkWin.csc
# TkWin.fs
# TkWin.fsc
# WmDefault.cs
# WmDefault.csc
# WmDefault.fs
# WmDefault.fsc
# WmDefault.py
# WmDefault.tcl
# WmDefault.txt
# bgerror.tcl
# button.tcl
# choosedir.tcl
# clrpick.tcl
# comdlg.tcl
# console.tcl
# dialog.tcl
# entry.tcl
# focus.tcl
# fontchooser.tcl
# iconlist.tcl
# icons.tcl
# license.terms
# listbox.tcl
# megawidget.tcl
# menu.tcl
# mkpsenc.tcl
# msgbox.tcl
# obsolete.tcl
# optMenu.tcl
# palette.tcl
# panedwindow.tcl
# pkgIndex.tcl
# safetk.tcl
# scale.tcl
# scrlbar.tcl
# spinbox.tcl
# tclIndex
# tearoff.tcl
# text.tcl
# tk.tcl
# tkfbox.tcl
# unsupported.tcl
# xmfbox.tcl
# anilabel.tcl
# aniwave.tcl
# arrow.tcl
# bind.tcl
# bitmap.tcl
# browse
# button.tcl
# check.tcl
# clrpick.tcl
# colors.tcl
# combo.tcl
# cscroll.tcl
# ctext.tcl
# dialog1.tcl
# dialog2.tcl
# en.msg
# entry1.tcl
# entry2.tcl
# entry3.tcl
# filebox.tcl
# floor.tcl
# fontchoose.tcl
# form.tcl
# goldberg.tcl
# hello
# hscale.tcl
# icon.tcl
# image1.tcl
# image2.tcl
# items.tcl
# ixset
# knightstour.tcl
# label.tcl
# labelframe.tcl
# license.terms
# mclist.tcl
# menu.tcl
# menubu.tcl
# msgbox.tcl
# nl.msg
# paned1.tcl
# paned2.tcl
# pendulum.tcl
# plot.tcl
# puzzle.tcl
# radio.tcl
# README
# rmt
# rolodex
# ruler.tcl
# sayings.tcl
# search.tcl
# spin.tcl
# square
# states.tcl
# style.tcl
# tclIndex
# tcolor
# text.tcl
# textpeer.tcl
# timer
# toolbar.tcl
# tree.tcl
# ttkbut.tcl
# ttkmenu.tcl
# ttknote.tcl
# ttkpane.tcl
# ttkprogress.tcl
# ttkscale.tcl
# twind.tcl
# unicodeout.tcl
# vscale.tcl
# widget
# earth.gif
# earthmenu.png
# earthris.gif
# flagdown.xbm
# flagup.xbm
# gray25.xbm
# letters.xbm
# noletter.xbm
# ouster.png
# pattern.xbm
# tcllogo.gif
# teapot.ppm
# logo.eps
# logo100.gif
# logo64.gif
# logoLarge.gif
# logoMed.gif
# pwrdLogo.eps
# pwrdLogo100.gif
# pwrdLogo150.gif
# pwrdLogo175.gif
# pwrdLogo200.gif
# pwrdLogo75.gif
# README
# tai-ku.gif
# cs.msg
# da.msg
# de.msg
# el.msg
# en.msg
# en_gb.msg
# eo.msg
# es.msg
# fr.msg
# hu.msg
# it.msg
# nl.msg
# pl.msg
# pt.msg
# ru.msg
# sv.msg
# altTheme.tcl
# aquaTheme.tcl
# button.tcl
# clamTheme.tcl
# classicTheme.tcl
# combobox.tcl
# cursors.tcl
# defaults.tcl
# entry.tcl
# fonts.tcl
# menubutton.tcl
# notebook.tcl
# panedwindow.tcl
# progress.tcl
# scale.tcl
# scrollbar.tcl
# sizegrip.tcl
# spinbox.tcl
# treeview.tcl
# ttk.tcl
# utils.tcl
# vistaTheme.tcl
# winTheme.tcl
# xpTheme.tcl
# beer.py
# eiffel.py
# hanoi.py
# life.py
# markov.py
# mcast.py
# queens.py
# redemo.py
# rpython.py
# rpythond.py
# sortvisu.py
# ss1.py
# vector.py
# beer.cpython-37.pyc
# eiffel.cpython-37.pyc
# hanoi.cpython-37.pyc
# life.cpython-37.pyc
# markov.cpython-37.pyc
# mcast.cpython-37.pyc
# queens.cpython-37.pyc
# redemo.cpython-37.pyc
# rpython.cpython-37.pyc
# rpythond.cpython-37.pyc
# sortvisu.cpython-37.pyc
# ss1.cpython-37.pyc
# vector.cpython-37.pyc
# makelocalealias.py
# msgfmt.py
# pygettext.py
# makelocalealias.cpython-37.pyc
# msgfmt.cpython-37.pyc
# pygettext.cpython-37.pyc
# unparse.py
# unparse.cpython-37.pyc
# ChipViewer.py
# ColorDB.py
# DetailsViewer.py
# html40colors.txt
# ListViewer.py
# Main.py
# namedcolors.txt
# pyColorChooser.py
# pynche.pyw
# PyncheWidget.py
# StripViewer.py
# Switchboard.py
# TextViewer.py
# TypeinViewer.py
# webcolors.txt
# websafe.txt
# __init__.py
# rgb.txt
# xlicense.txt
# ChipViewer.cpython-37.pyc
# ColorDB.cpython-37.pyc
# DetailsViewer.cpython-37.pyc
# ListViewer.cpython-37.pyc
# Main.cpython-37.pyc
# pyColorChooser.cpython-37.pyc
# PyncheWidget.cpython-37.pyc
# StripViewer.cpython-37.pyc
# Switchboard.cpython-37.pyc
# TextViewer.cpython-37.pyc
# TypeinViewer.cpython-37.pyc
# __init__.cpython-37.pyc
# 2to3.py
# abitype.py
# analyze_dxp.py
# byext.py
# byteyears.py
# checkpip.py
# checkpyc.py
# cleanfuture.py
# combinerefs.py
# copytime.py
# crlf.py
# db2pickle.py
# diff.py
# dutree.py
# eptags.py
# find-uname.py
# finddiv.py
# findlinksto.py
# findnocoding.py
# find_recursionlimit.py
# fixcid.py
# fixdiv.py
# fixheader.py
# fixnotice.py
# fixps.py
# generate_opcode_h.py
# get-remote-certificate.py
# google.py
# gprof2html.py
# h2py.py
# highlight.py
# ifdef.py
# import_diagnostics.py
# lfcr.py
# linktree.py
# lll.py
# mailerdaemon.py
# make_ctype.py
# md5sum.py
# mkreal.py
# ndiff.py
# nm2def.py
# objgraph.py
# parseentities.py
# parse_html5_entities.py
# patchcheck.py
# pathfix.py
# pdeps.py
# pickle2db.py
# pindent.py
# ptags.py
# pydoc3.py
# pysource.py
# pyvenv.py
# reindent-rst.py
# reindent.py
# rgrep.py
# run_tests.py
# serve.py
# smelly.py
# suff.py
# texi2html.py
# untabify.py
# update_file.py
# which.py
# win_add2path.py
# 2to3.cpython-37.pyc
# abitype.cpython-37.pyc
# analyze_dxp.cpython-37.pyc
# byext.cpython-37.pyc
# byteyears.cpython-37.pyc
# checkpip.cpython-37.pyc
# checkpyc.cpython-37.pyc
# cleanfuture.cpython-37.pyc
# combinerefs.cpython-37.pyc
# copytime.cpython-37.pyc
# crlf.cpython-37.pyc
# db2pickle.cpython-37.pyc
# diff.cpython-37.pyc
# dutree.cpython-37.pyc
# eptags.cpython-37.pyc
# find-uname.cpython-37.pyc
# finddiv.cpython-37.pyc
# findlinksto.cpython-37.pyc
# findnocoding.cpython-37.pyc
# find_recursionlimit.cpython-37.pyc
# fixcid.cpython-37.pyc
# fixdiv.cpython-37.pyc
# fixheader.cpython-37.pyc
# fixnotice.cpython-37.pyc
# fixps.cpython-37.pyc
# generate_opcode_h.cpython-37.pyc
# get-remote-certificate.cpython-37.pyc
# google.cpython-37.pyc
# gprof2html.cpython-37.pyc
# h2py.cpython-37.pyc
# highlight.cpython-37.pyc
# ifdef.cpython-37.pyc
# import_diagnostics.cpython-37.pyc
# lfcr.cpython-37.pyc
# linktree.cpython-37.pyc
# lll.cpython-37.pyc
# mailerdaemon.cpython-37.pyc
# make_ctype.cpython-37.pyc
# md5sum.cpython-37.pyc
# mkreal.cpython-37.pyc
# ndiff.cpython-37.pyc
# nm2def.cpython-37.pyc
# objgraph.cpython-37.pyc
# parseentities.cpython-37.pyc
# parse_html5_entities.cpython-37.pyc
# patchcheck.cpython-37.pyc
# pathfix.cpython-37.pyc
# pdeps.cpython-37.pyc
# pickle2db.cpython-37.pyc
# pindent.cpython-37.pyc
# ptags.cpython-37.pyc
# pydoc3.cpython-37.pyc
# pysource.cpython-37.pyc
# pyvenv.cpython-37.pyc
# reindent-rst.cpython-37.pyc
# reindent.cpython-37.pyc
# rgrep.cpython-37.pyc
# run_tests.cpython-37.pyc
# serve.cpython-37.pyc
# smelly.cpython-37.pyc
# suff.cpython-37.pyc
# texi2html.cpython-37.pyc
# untabify.cpython-37.pyc
# update_file.cpython-37.pyc
# which.cpython-37.pyc
# win_add2path.cpython-37.pyc
# conda.fish
# jupyter_notebook_config.json
# jupyterlab.json
# jupyterlab.json
# nbclassic.json
# notebook.json
# jupyterlab-plotly.json
# widgetsnbextension.json
# conda.csh
# conda.sh
# imagehash.png
# abstract.h
# asdl.h
# ast.h
# bitset.h
# bltinmodule.h
# boolobject.h
# bytearrayobject.h
# bytesobject.h
# cellobject.h
# ceval.h
# classobject.h
# code.h
# codecs.h
# compile.h
# complexobject.h
# context.h
# datetime.h
# descrobject.h

# %% [markdown]
# ## 5. Create a list of all of the files in your parent directory (minimum five files should be available).

# %%
import os 
os.listdir()

# %% [markdown]
# ## 6. Use multiprocessing to create three separate processes. Make each one wait a random number of seconds between one and five, print the current time, and then exit.

# %%
import multiprocessing
import time 
import random
import datetime

def procOne():
    print(f'Proc_one_Starttime -> {datetime.datetime.now()}')
    time.sleep(random.randint(1,5))
    print(f'Proc_one_Endtime -> {datetime.datetime.now()}')
    
def procTwo():
    print(f'Proc_two_Starttime -> {datetime.datetime.now()}')
    time.sleep(random.randint(1,5))
    print(f'Proc_two_Endtime -> {datetime.datetime.now()}')

def procThree():
    print(f'Proc_two_Starttime -> {datetime.datetime.now()}')
    time.sleep(random.randint(1,5))
    print(f'Proc_two_Endtime -> {datetime.datetime.now()}')
    
if __name__ == "__main__":    
    p1 = multiprocessing.Process(target=procOne)
    p2 = multiprocessing.Process(target=procTwo)
    p3 = multiprocessing.Process(target=procThree)

    p1.start()
    p2.start()
    p3.start()

    p1.join()
    p2.join()
    p3.join()

# %% [markdown]
# Due to some unknown reason. the above did not print any results in the jupyter cell. so i copied the code to a python file. executed it and pasted the ouput here
# `(base) C:\Users\vishnu.adepu\Desktop>python es_poc.py`
# `Proc_one_Starttime -> 2021-09-22 18:41:59.354061`
# `Proc_two_Starttime -> 2021-09-22 18:41:59.363712`
# `Proc_two_Starttime -> 2021-09-22 18:41:59.367238`
# `Proc_two_Endtime -> 2021-09-22 18:42:04.369860`
# `Proc_two_Endtime -> 2021-09-22 18:42:04.369860`
# `Proc_one_Endtime -> 2021-09-22 18:42:04.369860`

# %% [markdown]
# ## 7. Create a date object of your day of birth.

# %%
from datetime import datetime
my_dob = datetime.strptime('22/04/1997','%d/%m/%Y')
print(my_dob, type(my_dob))

# %% [markdown]
# ## 8. What day of the week was your day of birth?

# %%
from datetime import datetime
my_dob = datetime(1997,4,22)
my_dob.strftime("%A")

# %% [markdown]
# ## 9. When will you be (or when were you) 10,000 days old?

# %%
from datetime import datetime, timedelta
my_dob = datetime.strptime("22/04/1997",'%d/%m/%Y')
future_date = my_dob-timedelta(10000)
future_date
